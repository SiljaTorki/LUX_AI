# %%
from luxai_s3.params import EnvParams

from luxai_s3.wrappers import LuxAIS3GymEnv
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.callbacks import CallbackList, CheckpointCallback
import os
import sys
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecNormalize, SubprocVecEnv, DummyVecEnv
import torch

# Add the project root directory to the Python path
sys.path.append(os.path.abspath(".."))
from wrappers.static_planner_wrapper import SB3LuxEnvStaticPlanner
from common.helper import EnhancedTensorboardCallback, make_env, custom_env_check, linear_schedule

# %% [markdown]
# ## Check if the environment is compatible with SB3

# %%
# Create the base environment
base_env = LuxAIS3GymEnv()
# Create environment parameters
env_params = EnvParams(map_type=0, max_steps_in_match=100)

# Apply our wrapper with explicit player_id and opponent strategy
wrapped_env = SB3LuxEnvStaticPlanner(base_env, player_id='player_0', opponent_strategy='random')

# Create the environment
env = make_env(env_params, wrapped_env, seed=367)  # Using a fixed seed for reproducibility

# Print observation space shape
print(f"Observation space: {env.observation_space}")
print(f"Action space: {env.action_space}")

check_env(env)
print("Environment check passed successfully!")
# Out:
# Observation space: Dict('env_cfg_map_height': Box(0, 24, (1,), int32), 'env_cfg_map_width': Box(0, 24, (1,), int32), 'env_cfg_max_steps_in_match': Box(0, 100, (1,), int32), 'env_cfg_unit_move_cost': Box(0, 100, (1,), int32), 'env_cfg_unit_sap_cost': Box(0, 100, (1,), int32), 'env_cfg_unit_sap_range': Box(0, 100, (1,), int32), 'map_features_energy': Box(-1, 20, (24, 24), int8), 'map_features_tile_type': Box(-1, 2, (24, 24), int8), 'match_steps': Box(0, 100, (1,), int32), 'relic_nodes': Box(-1, 23, (6, 2), int32), 'relic_nodes_mask': Box(0, 1, (6,), int8), 'remainingOverageTime': Box(0, 1000, (1,), int32), 'sensor_mask': Box(0, 1, (24, 24), int8), 'steps': Box(0, 100, (1,), int32), 'team_points': Box(0, 1000, (2,), int32), 'team_wins': Box(0, 1000, (2,), int32), 'units_energy': Box(0, 400, (2, 16, 1), int32), 'units_mask': Box(0, 1, (2, 16), int8), 'units_position': Box(-1, 575, (2, 16, 2), int32))
# Action space: MultiDiscrete([6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6])
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: Your observation map_features_energy has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: Your observation map_features_tile_type has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: Your observation relic_nodes has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: Your observation sensor_mask has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:55: UserWarning: It seems that your observation units_energy is an image but its `dtype` is (int32) whereas it has to be `np.uint8`. If your observation is not an image, we recommend you to flatten the observation to have only a 1D vector
#   warnings.warn(
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:63: UserWarning: It seems that your observation space units_energy is an image but the upper and lower bounds are not in [0, 255]. Because the CNN policy normalize automatically the observation you may encounter issue if the values are not in that range.
#   warnings.warn(
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:76: UserWarning: The minimal resolution for an image is 36x36 for the default `CnnPolicy`. You might need to use a custom features extractor cf. https://stable-baselines3.readthedocs.io/en/master/guide/custom_policy.html
#   warnings.warn(
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: Your observation units_mask has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:55: UserWarning: It seems that your observation units_position is an image but its `dtype` is (int32) whereas it has to be `np.uint8`. If your observation is not an image, we recommend you to flatten the observation to have only a 1D vector
#   warnings.warn(
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:63: UserWarning: It seems that your observation space units_position is an image but the upper and lower bounds are not in [0, 255]. Because the CNN policy normalize automatically the observation you may encounter issue if the values are not in that range.
#   warnings.warn(
# Environment check passed successfully!

# %% [markdown]
# #### Custom enviorment check 🤖

# %%
# custom_env_check(env, 2)

# %% [markdown]
# ### Train the base PPO model

# %%
models_dir = "../ppo_lux_model_static_planner/"
SAVE_FREQUENCY = 1000

envs = SubprocVecEnv(
    [lambda: make_env(env_params, wrapped_env, seed=i) for i in range(8)]
)
envs = VecNormalize(envs, norm_obs=True, norm_reward=True)

# Create callbacks
enchared_tb_callback = EnhancedTensorboardCallback()
checkpoint_callback = CheckpointCallback(
    save_freq=SAVE_FREQUENCY, save_path=models_dir, name_prefix="ppo_lux_model_static_planner"
)

# Combine callbacks
callbacks = CallbackList([enchared_tb_callback, checkpoint_callback])

mps_device = None
if not torch.backends.mps.is_available():
    if not torch.backends.mps.is_built():
        print(
            "MPS not available because the current PyTorch install was not "
            "built with MPS enabled."
        )
    else:
        print(
            "MPS not available because the current MacOS version is not 12.3+ "
            "and/or you do not have an MPS-enabled device on this machine."
        )
else:
    mps_device = torch.device("mps")

    print("MPS available and enabled.")

# Create PPO model
model = PPO(
    "MultiInputPolicy",
    envs,
    verbose=1,
    learning_rate=linear_schedule(5e-4, 1e-4),
    n_steps=2048,
    batch_size=128,
    n_epochs=5,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    vf_coef=0.25,
    ent_coef=3.0,
    clip_range_vf=0.2,
    tensorboard_log="./ppo_lux_tensorboard/",
    device=mps_device,
    policy_kwargs=dict(net_arch=[512, 256, 128], activation_fn=torch.nn.ReLU),
)

# Train the model with callbacks
model.learn(total_timesteps=1000000, callback=callbacks)

# Save final model
model.save("ppo_lux_model_static_planner")
# Out:
# MPS available and enabled.
# Using mps device
# Logging to ./ppo_lux_tensorboard/PPO_2
# -------------------------------------------------
# | lux/                               |          |
# |    energy_collected                | 9        |
# |    final_reward                    | 16.6     |
# |    map_coverage                    | 6.08     |
# |    new_tiles_revealed              | 3        |
# |    point_reward                    | 0        |
# |    points_earned                   | 0        |
# |    relic_control_streak            | 0        |
# |    relic_point_tiles_found         | 0        |
# |    rule_reward                     | 16.6     |
# |    sap_actions_taken               | 3        |
# |    sap_reward                      | 0        |
# |    static_planner_bonus_sap_reward | 6        |
# |    total_energy                    | 90       |
# |    visited_tiles_count             | 9        |
# |    win_rate                        | 0        |
# | time/                              |          |
# |    fps                             | 101      |
# |    iterations                      | 1        |
# |    time_elapsed                    | 161      |
# |    total_timesteps                 | 16384    |
# -------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 0            |
# |    final_reward                    | 49.8         |
# |    map_coverage                    | 10.8         |
# |    new_tiles_revealed              | 3            |
# |    point_reward                    | 0            |
# |    points_earned                   | 1            |
# |    relic_control_streak            | 1            |
# |    relic_point_tiles_found         | 2            |
# |    rule_reward                     | 49.8         |
# |    sap_actions_taken               | 1            |
# |    sap_reward                      | 0            |
# |    static_planner_bonus_sap_reward | 2            |
# |    total_energy                    | 33           |
# |    visited_tiles_count             | 16           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 96           |
# |    iterations                      | 2            |
# |    time_elapsed                    | 339          |
# |    total_timesteps                 | 32768        |
# | train/                             |              |
# |    approx_kl                       | 0.0065604225 |
# |    clip_fraction                   | 0.0396       |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | -0.125       |
# |    learning_rate                   | 0.000493     |
# |    loss                            | -85.9        |
# |    n_updates                       | 5            |
# |    policy_gradient_loss            | -0.0227      |
# |    value_loss                      | 0.653        |
# -----------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 4            |
# |    final_reward                    | 14.5         |
# |    map_coverage                    | 17           |
# |    new_tiles_revealed              | 1            |
# |    point_reward                    | 0            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | 14.5         |
# |    sap_actions_taken               | 2            |
# |    sap_reward                      | -1           |
# |    static_planner_bonus_sap_reward | 4            |
# |    total_energy                    | 77           |
# |    visited_tiles_count             | 19           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 94           |
# |    iterations                      | 3            |
# |    time_elapsed                    | 517          |
# |    total_timesteps                 | 49152        |
# | train/                             |              |
# |    approx_kl                       | 0.0045416914 |
# |    clip_fraction                   | 0.0265       |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.334        |
# |    learning_rate                   | 0.000487     |
# |    loss                            | -86          |
# |    n_updates                       | 10           |
# |    policy_gradient_loss            | -0.0141      |
# |    value_loss                      | 0.116        |
# -----------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 12           |
# |    final_reward                    | 4.21         |
# |    map_coverage                    | 13.7         |
# |    new_tiles_revealed              | 0            |
# |    point_reward                    | 1            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 4            |
# |    rule_reward                     | 4.21         |
# |    sap_actions_taken               | 3            |
# |    sap_reward                      | -1           |
# |    static_planner_bonus_sap_reward | 6            |
# |    total_energy                    | 400          |
# |    visited_tiles_count             | 35           |
# |    win_rate                        | 1            |
# | time/                              |              |
# |    fps                             | 94           |
# |    iterations                      | 4            |
# |    time_elapsed                    | 692          |
# |    total_timesteps                 | 65536        |
# | train/                             |              |
# |    approx_kl                       | 0.0038529811 |
# |    clip_fraction                   | 0.0276       |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | -0.343       |
# |    learning_rate                   | 0.00048      |
# |    loss                            | -86          |
# |    n_updates                       | 15           |
# |    policy_gradient_loss            | -0.00652     |
# |    value_loss                      | 0.039        |
# -----------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 0            |
# |    final_reward                    | 16           |
# |    map_coverage                    | 18.6         |
# |    new_tiles_revealed              | 3            |
# |    point_reward                    | 0            |
# |    points_earned                   | 1            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 14           |
# |    rule_reward                     | 16           |
# |    sap_actions_taken               | 0            |
# |    sap_reward                      | 0            |
# |    static_planner_bonus_sap_reward | 0            |
# |    total_energy                    | 208          |
# |    visited_tiles_count             | 46           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 94           |
# |    iterations                      | 5            |
# |    time_elapsed                    | 871          |
# |    total_timesteps                 | 81920        |
# | train/                             |              |
# |    approx_kl                       | 0.0018813163 |
# |    clip_fraction                   | 0.00621      |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | -0.0563      |
# |    learning_rate                   | 0.000474     |
# |    loss                            | -86          |
# |    n_updates                       | 20           |
# |    policy_gradient_loss            | -0.00415     |
# |    value_loss                      | 0.0185       |
# -----------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 15           |
# |    final_reward                    | 15.7         |
# |    map_coverage                    | 21.5         |
# |    new_tiles_revealed              | 3            |
# |    point_reward                    | 0            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | 15.7         |
# |    sap_actions_taken               | 2            |
# |    sap_reward                      | -0.5         |
# |    static_planner_bonus_sap_reward | 4            |
# |    total_energy                    | 655          |
# |    visited_tiles_count             | 55           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 93           |
# |    iterations                      | 6            |
# |    time_elapsed                    | 1049         |
# |    total_timesteps                 | 98304        |
# | train/                             |              |
# |    approx_kl                       | 0.0021039736 |
# |    clip_fraction                   | 0.0108       |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.438        |
# |    learning_rate                   | 0.000467     |
# |    loss                            | -86          |
# |    n_updates                       | 25           |
# |    policy_gradient_loss            | -0.00597     |
# |    value_loss                      | 0.00563      |
# -----------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 1             |
# |    final_reward                    | -7.67         |
# |    map_coverage                    | 39.1          |
# |    new_tiles_revealed              | 0             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 1             |
# |    rule_reward                     | -7.67         |
# |    sap_actions_taken               | 4             |
# |    sap_reward                      | -3            |
# |    static_planner_bonus_sap_reward | 8             |
# |    total_energy                    | 7             |
# |    visited_tiles_count             | 57            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 93            |
# |    iterations                      | 7             |
# |    time_elapsed                    | 1230          |
# |    total_timesteps                 | 114688        |
# | train/                             |               |
# |    approx_kl                       | 0.00095782673 |
# |    clip_fraction                   | 0.00327       |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.299         |
# |    learning_rate                   | 0.000461      |
# |    loss                            | -86           |
# |    n_updates                       | 30            |
# |    policy_gradient_loss            | -0.00159      |
# |    value_loss                      | 0.0128        |
# ------------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 97           |
# |    final_reward                    | -9.76        |
# |    map_coverage                    | 17           |
# |    new_tiles_revealed              | 0            |
# |    point_reward                    | 0            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | -9.76        |
# |    sap_actions_taken               | 1            |
# |    sap_reward                      | 0            |
# |    static_planner_bonus_sap_reward | 2            |
# |    total_energy                    | 408          |
# |    visited_tiles_count             | 40           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 92           |
# |    iterations                      | 8            |
# |    time_elapsed                    | 1409         |
# |    total_timesteps                 | 131072       |
# | train/                             |              |
# |    approx_kl                       | 0.0013687349 |
# |    clip_fraction                   | 0.00587      |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.541        |
# |    learning_rate                   | 0.000454     |
# |    loss                            | -86          |
# |    n_updates                       | 35           |
# |    policy_gradient_loss            | -0.0023      |
# |    value_loss                      | 0.00296      |
# -----------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 0             |
# |    final_reward                    | -2.56         |
# |    map_coverage                    | 31.1          |
# |    new_tiles_revealed              | 0             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 0             |
# |    rule_reward                     | -2.56         |
# |    sap_actions_taken               | 3             |
# |    sap_reward                      | -3            |
# |    static_planner_bonus_sap_reward | 6             |
# |    total_energy                    | 191           |
# |    visited_tiles_count             | 41            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 92            |
# |    iterations                      | 9             |
# |    time_elapsed                    | 1587          |
# |    total_timesteps                 | 147456        |
# | train/                             |               |
# |    approx_kl                       | 0.00092216337 |
# |    clip_fraction                   | 0.00193       |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.48          |
# |    learning_rate                   | 0.000448      |
# |    loss                            | -86           |
# |    n_updates                       | 40            |
# |    policy_gradient_loss            | -0.0015       |
# |    value_loss                      | 0.00303       |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 3             |
# |    final_reward                    | 48.8          |
# |    map_coverage                    | 24            |
# |    new_tiles_revealed              | 1             |
# |    point_reward                    | 1             |
# |    points_earned                   | 1             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 16            |
# |    rule_reward                     | 48.8          |
# |    sap_actions_taken               | 2             |
# |    sap_reward                      | -2            |
# |    static_planner_bonus_sap_reward | 4             |
# |    total_energy                    | 194           |
# |    visited_tiles_count             | 45            |
# |    win_rate                        | 0.5           |
# | time/                              |               |
# |    fps                             | 92            |
# |    iterations                      | 10            |
# |    time_elapsed                    | 1766          |
# |    total_timesteps                 | 163840        |
# | train/                             |               |
# |    approx_kl                       | 0.00073427183 |
# |    clip_fraction                   | 0.00236       |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.324         |
# |    learning_rate                   | 0.000441      |
# |    loss                            | -86           |
# |    n_updates                       | 45            |
# |    policy_gradient_loss            | -0.000997     |
# |    value_loss                      | 0.0354        |
# ------------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 0            |
# |    final_reward                    | 19.7         |
# |    map_coverage                    | 9.55         |
# |    new_tiles_revealed              | 2            |
# |    point_reward                    | 2            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 34           |
# |    rule_reward                     | 19.7         |
# |    sap_actions_taken               | 1            |
# |    sap_reward                      | -1           |
# |    static_planner_bonus_sap_reward | 2            |
# |    total_energy                    | 184          |
# |    visited_tiles_count             | 35           |
# |    win_rate                        | 0.667        |
# | time/                              |              |
# |    fps                             | 92           |
# |    iterations                      | 11           |
# |    time_elapsed                    | 1946         |
# |    total_timesteps                 | 180224       |
# | train/                             |              |
# |    approx_kl                       | 0.0008281041 |
# |    clip_fraction                   | 0.00267      |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.693        |
# |    learning_rate                   | 0.000434     |
# |    loss                            | -86          |
# |    n_updates                       | 50           |
# |    policy_gradient_loss            | -0.00188     |
# |    value_loss                      | 0.00211      |
# -----------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 0            |
# |    final_reward                    | -19.6        |
# |    map_coverage                    | 24.3         |
# |    new_tiles_revealed              | 0            |
# |    point_reward                    | 0            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | -19.6        |
# |    sap_actions_taken               | 5            |
# |    sap_reward                      | -5           |
# |    static_planner_bonus_sap_reward | 10           |
# |    total_energy                    | 174          |
# |    visited_tiles_count             | 52           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 92           |
# |    iterations                      | 12           |
# |    time_elapsed                    | 2126         |
# |    total_timesteps                 | 196608       |
# | train/                             |              |
# |    approx_kl                       | 0.0007623454 |
# |    clip_fraction                   | 0.00186      |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.472        |
# |    learning_rate                   | 0.000428     |
# |    loss                            | -86          |
# |    n_updates                       | 55           |
# |    policy_gradient_loss            | -0.00148     |
# |    value_loss                      | 0.0244       |
# -----------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 8            |
# |    final_reward                    | 48.4         |
# |    map_coverage                    | 33.9         |
# |    new_tiles_revealed              | 3            |
# |    point_reward                    | 1            |
# |    points_earned                   | 2            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 43           |
# |    rule_reward                     | 48.4         |
# |    sap_actions_taken               | 3            |
# |    sap_reward                      | -3           |
# |    static_planner_bonus_sap_reward | 6            |
# |    total_energy                    | 724          |
# |    visited_tiles_count             | 71           |
# |    win_rate                        | 0.333        |
# | time/                              |              |
# |    fps                             | 92           |
# |    iterations                      | 13           |
# |    time_elapsed                    | 2307         |
# |    total_timesteps                 | 212992       |
# | train/                             |              |
# |    approx_kl                       | 0.0004934774 |
# |    clip_fraction                   | 0.000476     |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.496        |
# |    learning_rate                   | 0.000421     |
# |    loss                            | -86          |
# |    n_updates                       | 60           |
# |    policy_gradient_loss            | -0.000695    |
# |    value_loss                      | 0.0159       |
# -----------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 0            |
# |    final_reward                    | -9.28        |
# |    map_coverage                    | 15.5         |
# |    new_tiles_revealed              | 2            |
# |    point_reward                    | 1            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | -9.28        |
# |    sap_actions_taken               | 0            |
# |    sap_reward                      | 0            |
# |    static_planner_bonus_sap_reward | 0            |
# |    total_energy                    | 37           |
# |    visited_tiles_count             | 53           |
# |    win_rate                        | 0.333        |
# | time/                              |              |
# |    fps                             | 92           |
# |    iterations                      | 14           |
# |    time_elapsed                    | 2490         |
# |    total_timesteps                 | 229376       |
# | train/                             |              |
# |    approx_kl                       | 0.0005921499 |
# |    clip_fraction                   | 9.77e-05     |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.457        |
# |    learning_rate                   | 0.000415     |
# |    loss                            | -86          |
# |    n_updates                       | 65           |
# |    policy_gradient_loss            | -0.000838    |
# |    value_loss                      | 0.0148       |
# -----------------------------------------------------
# ----------------------------------------------------
# | lux/                               |             |
# |    energy_collected                | 67          |
# |    final_reward                    | -49.4       |
# |    map_coverage                    | 20          |
# |    new_tiles_revealed              | 1           |
# |    point_reward                    | 0           |
# |    points_earned                   | 0           |
# |    relic_control_streak            | 0           |
# |    relic_point_tiles_found         | 3           |
# |    rule_reward                     | -49.4       |
# |    sap_actions_taken               | 5           |
# |    sap_reward                      | -5          |
# |    static_planner_bonus_sap_reward | 10          |
# |    total_energy                    | 415         |
# |    visited_tiles_count             | 63          |
# |    win_rate                        | 0           |
# | time/                              |             |
# |    fps                             | 92          |
# |    iterations                      | 15          |
# |    time_elapsed                    | 2671        |
# |    total_timesteps                 | 245760      |
# | train/                             |             |
# |    approx_kl                       | 0.000456307 |
# |    clip_fraction                   | 0.000354    |
# |    clip_range                      | 0.2         |
# |    clip_range_vf                   | 0.2         |
# |    entropy_loss                    | -28.7       |
# |    explained_variance              | 0.539       |
# |    learning_rate                   | 0.000408    |
# |    loss                            | -86         |
# |    n_updates                       | 70          |
# |    policy_gradient_loss            | -0.000631   |
# |    value_loss                      | 0.0561      |
# ----------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 10           |
# |    final_reward                    | 205          |
# |    map_coverage                    | 36.5         |
# |    new_tiles_revealed              | 6            |
# |    point_reward                    | 0            |
# |    points_earned                   | 4            |
# |    relic_control_streak            | 1            |
# |    relic_point_tiles_found         | 52           |
# |    rule_reward                     | 205          |
# |    sap_actions_taken               | 0            |
# |    sap_reward                      | 0            |
# |    static_planner_bonus_sap_reward | 0            |
# |    total_energy                    | 776          |
# |    visited_tiles_count             | 73           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 91           |
# |    iterations                      | 16           |
# |    time_elapsed                    | 2852         |
# |    total_timesteps                 | 262144       |
# | train/                             |              |
# |    approx_kl                       | 0.0007255553 |
# |    clip_fraction                   | 0.000269     |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.647        |
# |    learning_rate                   | 0.000402     |
# |    loss                            | -86          |
# |    n_updates                       | 75           |
# |    policy_gradient_loss            | -0.00108     |
# |    value_loss                      | 0.131        |
# -----------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 5             |
# |    final_reward                    | 40.8          |
# |    map_coverage                    | 17.4          |
# |    new_tiles_revealed              | 0             |
# |    point_reward                    | 3             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 24            |
# |    rule_reward                     | 40.8          |
# |    sap_actions_taken               | 5             |
# |    sap_reward                      | -5            |
# |    static_planner_bonus_sap_reward | 10            |
# |    total_energy                    | 123           |
# |    visited_tiles_count             | 53            |
# |    win_rate                        | 0.75          |
# | time/                              |               |
# |    fps                             | 91            |
# |    iterations                      | 17            |
# |    time_elapsed                    | 3030          |
# |    total_timesteps                 | 278528        |
# | train/                             |               |
# |    approx_kl                       | 0.00051087455 |
# |    clip_fraction                   | 0             |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.641         |
# |    learning_rate                   | 0.000395      |
# |    loss                            | -86           |
# |    n_updates                       | 80            |
# |    policy_gradient_loss            | -0.000777     |
# |    value_loss                      | 0.0425        |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 48            |
# |    final_reward                    | 212           |
# |    map_coverage                    | 24.5          |
# |    new_tiles_revealed              | 3             |
# |    point_reward                    | 1             |
# |    points_earned                   | 17            |
# |    relic_control_streak            | 16            |
# |    relic_point_tiles_found         | 42            |
# |    rule_reward                     | 212           |
# |    sap_actions_taken               | 3             |
# |    sap_reward                      | -3            |
# |    static_planner_bonus_sap_reward | 6             |
# |    total_energy                    | 207           |
# |    visited_tiles_count             | 75            |
# |    win_rate                        | 0.25          |
# | time/                              |               |
# |    fps                             | 91            |
# |    iterations                      | 18            |
# |    time_elapsed                    | 3210          |
# |    total_timesteps                 | 294912        |
# | train/                             |               |
# |    approx_kl                       | 0.00058161456 |
# |    clip_fraction                   | 9.77e-05      |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.776         |
# |    learning_rate                   | 0.000389      |
# |    loss                            | -86           |
# |    n_updates                       | 85            |
# |    policy_gradient_loss            | -0.000761     |
# |    value_loss                      | 0.0181        |
# ------------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 0            |
# |    final_reward                    | 0.985        |
# |    map_coverage                    | 6.94         |
# |    new_tiles_revealed              | 0            |
# |    point_reward                    | 0            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | 0.985        |
# |    sap_actions_taken               | 2            |
# |    sap_reward                      | 0            |
# |    static_planner_bonus_sap_reward | 4            |
# |    total_energy                    | 46           |
# |    visited_tiles_count             | 6            |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 91           |
# |    iterations                      | 19           |
# |    time_elapsed                    | 3390         |
# |    total_timesteps                 | 311296       |
# | train/                             |              |
# |    approx_kl                       | 0.0005323212 |
# |    clip_fraction                   | 0            |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.566        |
# |    learning_rate                   | 0.000382     |
# |    loss                            | -86          |
# |    n_updates                       | 90           |
# |    policy_gradient_loss            | -0.0011      |
# |    value_loss                      | 0.056        |
# -----------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 0             |
# |    final_reward                    | 4.77          |
# |    map_coverage                    | 21.4          |
# |    new_tiles_revealed              | 3             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 0             |
# |    rule_reward                     | 4.77          |
# |    sap_actions_taken               | 2             |
# |    sap_reward                      | -1            |
# |    static_planner_bonus_sap_reward | 4             |
# |    total_energy                    | 0             |
# |    visited_tiles_count             | 20            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 91            |
# |    iterations                      | 20            |
# |    time_elapsed                    | 3569          |
# |    total_timesteps                 | 327680        |
# | train/                             |               |
# |    approx_kl                       | 0.00062177837 |
# |    clip_fraction                   | 0.000244      |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.558         |
# |    learning_rate                   | 0.000375      |
# |    loss                            | -86           |
# |    n_updates                       | 95            |
# |    policy_gradient_loss            | -0.000576     |
# |    value_loss                      | 0.135         |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 1             |
# |    final_reward                    | 4.3           |
# |    map_coverage                    | 14.6          |
# |    new_tiles_revealed              | 0             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 0             |
# |    rule_reward                     | 4.3           |
# |    sap_actions_taken               | 2             |
# |    sap_reward                      | -1            |
# |    static_planner_bonus_sap_reward | 4             |
# |    total_energy                    | 177           |
# |    visited_tiles_count             | 28            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 71            |
# |    iterations                      | 21            |
# |    time_elapsed                    | 4780          |
# |    total_timesteps                 | 344064        |
# | train/                             |               |
# |    approx_kl                       | 0.00045595033 |
# |    clip_fraction                   | 0             |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.577         |
# |    learning_rate                   | 0.000369      |
# |    loss                            | -86           |
# |    n_updates                       | 100           |
# |    policy_gradient_loss            | -0.000797     |
# |    value_loss                      | 0.108         |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 49            |
# |    final_reward                    | -4.87         |
# |    map_coverage                    | 32.5          |
# |    new_tiles_revealed              | 5             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 4             |
# |    rule_reward                     | -4.87         |
# |    sap_actions_taken               | 1             |
# |    sap_reward                      | -1            |
# |    static_planner_bonus_sap_reward | 2             |
# |    total_energy                    | 222           |
# |    visited_tiles_count             | 20            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 72            |
# |    iterations                      | 22            |
# |    time_elapsed                    | 4956          |
# |    total_timesteps                 | 360448        |
# | train/                             |               |
# |    approx_kl                       | 0.00068789255 |
# |    clip_fraction                   | 0             |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.665         |
# |    learning_rate                   | 0.000362      |
# |    loss                            | -86           |
# |    n_updates                       | 105           |
# |    policy_gradient_loss            | -0.00134      |
# |    value_loss                      | 0.0354        |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 0             |
# |    final_reward                    | -5.71         |
# |    map_coverage                    | 15.8          |
# |    new_tiles_revealed              | 0             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 0             |
# |    rule_reward                     | -5.71         |
# |    sap_actions_taken               | 4             |
# |    sap_reward                      | -1            |
# |    static_planner_bonus_sap_reward | 8             |
# |    total_energy                    | 303           |
# |    visited_tiles_count             | 36            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 73            |
# |    iterations                      | 23            |
# |    time_elapsed                    | 5132          |
# |    total_timesteps                 | 376832        |
# | train/                             |               |
# |    approx_kl                       | 0.00054801157 |
# |    clip_fraction                   | 1.22e-05      |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.807         |
# |    learning_rate                   | 0.000356      |
# |    loss                            | -86           |
# |    n_updates                       | 110           |
# |    policy_gradient_loss            | -0.000898     |
# |    value_loss                      | 0.0185        |
# ------------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 0            |
# |    final_reward                    | 81.3         |
# |    map_coverage                    | 26           |
# |    new_tiles_revealed              | 0            |
# |    point_reward                    | 0            |
# |    points_earned                   | 35           |
# |    relic_control_streak            | 18           |
# |    relic_point_tiles_found         | 3            |
# |    rule_reward                     | 81.3         |
# |    sap_actions_taken               | 3            |
# |    sap_reward                      | 0            |
# |    static_planner_bonus_sap_reward | 6            |
# |    total_energy                    | 0            |
# |    visited_tiles_count             | 29           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 74           |
# |    iterations                      | 24           |
# |    time_elapsed                    | 5307         |
# |    total_timesteps                 | 393216       |
# | train/                             |              |
# |    approx_kl                       | 0.0004544864 |
# |    clip_fraction                   | 0            |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.777        |
# |    learning_rate                   | 0.000349     |
# |    loss                            | -86          |
# |    n_updates                       | 115          |
# |    policy_gradient_loss            | -0.000511    |
# |    value_loss                      | 0.0343       |
# -----------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 0            |
# |    final_reward                    | 4.9          |
# |    map_coverage                    | 20.1         |
# |    new_tiles_revealed              | 1            |
# |    point_reward                    | 0            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | 4.9          |
# |    sap_actions_taken               | 4            |
# |    sap_reward                      | -1           |
# |    static_planner_bonus_sap_reward | 8            |
# |    total_energy                    | 79           |
# |    visited_tiles_count             | 61           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 74           |
# |    iterations                      | 25           |
# |    time_elapsed                    | 5482         |
# |    total_timesteps                 | 409600       |
# | train/                             |              |
# |    approx_kl                       | 0.0005228304 |
# |    clip_fraction                   | 0            |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.846        |
# |    learning_rate                   | 0.000343     |
# |    loss                            | -86          |
# |    n_updates                       | 120          |
# |    policy_gradient_loss            | -0.000819    |
# |    value_loss                      | 0.0783       |
# -----------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 28            |
# |    final_reward                    | -1.65         |
# |    map_coverage                    | 30.2          |
# |    new_tiles_revealed              | 0             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 0             |
# |    rule_reward                     | -1.65         |
# |    sap_actions_taken               | 5             |
# |    sap_reward                      | -2            |
# |    static_planner_bonus_sap_reward | 10            |
# |    total_energy                    | 642           |
# |    visited_tiles_count             | 74            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 75            |
# |    iterations                      | 26            |
# ...
# |    clip_fraction                   | 0             |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.748         |
# |    learning_rate                   | 0.000153      |
# |    loss                            | -86           |
# |    n_updates                       | 265           |
# |    policy_gradient_loss            | -0.000686     |
# |    value_loss                      | 0.00786       |
# ------------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 0            |
# |    final_reward                    | 6.49         |
# |    map_coverage                    | 8.85         |
# |    new_tiles_revealed              | 5            |
# |    point_reward                    | 0            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | 6.49         |
# |    sap_actions_taken               | 4            |
# |    sap_reward                      | 0            |
# |    static_planner_bonus_sap_reward | 8            |
# |    total_energy                    | 51           |
# |    visited_tiles_count             | 11           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 83           |
# |    iterations                      | 55           |
# |    time_elapsed                    | 10760        |
# |    total_timesteps                 | 901120       |
# | train/                             |              |
# |    approx_kl                       | 0.0002157394 |
# |    clip_fraction                   | 0            |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.756        |
# |    learning_rate                   | 0.000146     |
# |    loss                            | -86          |
# |    n_updates                       | 270          |
# |    policy_gradient_loss            | -0.000432    |
# |    value_loss                      | 0.0462       |
# -----------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 5             |
# |    final_reward                    | 0.895         |
# |    map_coverage                    | 7.64          |
# |    new_tiles_revealed              | 4             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 0             |
# |    rule_reward                     | 0.895         |
# |    sap_actions_taken               | 1             |
# |    sap_reward                      | 0             |
# |    static_planner_bonus_sap_reward | 2             |
# |    total_energy                    | 66            |
# |    visited_tiles_count             | 8             |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 83            |
# |    iterations                      | 56            |
# |    time_elapsed                    | 10933         |
# |    total_timesteps                 | 917504        |
# | train/                             |               |
# |    approx_kl                       | 0.00023525406 |
# |    clip_fraction                   | 0             |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.84          |
# |    learning_rate                   | 0.00014       |
# |    loss                            | -86           |
# |    n_updates                       | 275           |
# |    policy_gradient_loss            | -0.00069      |
# |    value_loss                      | 0.0931        |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 5             |
# |    final_reward                    | 5.38          |
# |    map_coverage                    | 25.5          |
# |    new_tiles_revealed              | 5             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 0             |
# |    rule_reward                     | 5.38          |
# |    sap_actions_taken               | 4             |
# |    sap_reward                      | -1            |
# |    static_planner_bonus_sap_reward | 8             |
# |    total_energy                    | 30            |
# |    visited_tiles_count             | 27            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 84            |
# |    iterations                      | 57            |
# |    time_elapsed                    | 11110         |
# |    total_timesteps                 | 933888        |
# | train/                             |               |
# |    approx_kl                       | 0.00023186863 |
# |    clip_fraction                   | 8.54e-05      |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.811         |
# |    learning_rate                   | 0.000133      |
# |    loss                            | -86           |
# |    n_updates                       | 280           |
# |    policy_gradient_loss            | -0.000578     |
# |    value_loss                      | 0.0159        |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 9             |
# |    final_reward                    | 4.74          |
# |    map_coverage                    | 16.7          |
# |    new_tiles_revealed              | 3             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 0             |
# |    rule_reward                     | 4.74          |
# |    sap_actions_taken               | 1             |
# |    sap_reward                      | -1            |
# |    static_planner_bonus_sap_reward | 2             |
# |    total_energy                    | 273           |
# |    visited_tiles_count             | 22            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 84            |
# |    iterations                      | 58            |
# |    time_elapsed                    | 11286         |
# |    total_timesteps                 | 950272        |
# | train/                             |               |
# |    approx_kl                       | 0.00015093313 |
# |    clip_fraction                   | 0             |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.829         |
# |    learning_rate                   | 0.000126      |
# |    loss                            | -86           |
# |    n_updates                       | 285           |
# |    policy_gradient_loss            | -0.000303     |
# |    value_loss                      | 0.0383        |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 32            |
# |    final_reward                    | -15.9         |
# |    map_coverage                    | 22.9          |
# |    new_tiles_revealed              | 0             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 0             |
# |    rule_reward                     | -15.9         |
# |    sap_actions_taken               | 1             |
# |    sap_reward                      | -1            |
# |    static_planner_bonus_sap_reward | 2             |
# |    total_energy                    | 77            |
# |    visited_tiles_count             | 15            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 84            |
# |    iterations                      | 59            |
# |    time_elapsed                    | 11462         |
# |    total_timesteps                 | 966656        |
# | train/                             |               |
# |    approx_kl                       | 0.00013908782 |
# |    clip_fraction                   | 0             |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.846         |
# |    learning_rate                   | 0.00012       |
# |    loss                            | -86           |
# |    n_updates                       | 290           |
# |    policy_gradient_loss            | -0.000363     |
# |    value_loss                      | 0.0284        |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 0             |
# |    final_reward                    | 8.4           |
# |    map_coverage                    | 20.5          |
# |    new_tiles_revealed              | 0             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 11            |
# |    rule_reward                     | 8.4           |
# |    sap_actions_taken               | 2             |
# |    sap_reward                      | -2            |
# |    static_planner_bonus_sap_reward | 4             |
# |    total_energy                    | 142           |
# |    visited_tiles_count             | 45            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 84            |
# |    iterations                      | 60            |
# |    time_elapsed                    | 11638         |
# |    total_timesteps                 | 983040        |
# | train/                             |               |
# |    approx_kl                       | 0.00032562698 |
# |    clip_fraction                   | 0.000928      |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.754         |
# |    learning_rate                   | 0.000113      |
# |    loss                            | -86           |
# |    n_updates                       | 295           |
# |    policy_gradient_loss            | -0.00159      |
# |    value_loss                      | 0.0134        |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 12            |
# |    final_reward                    | 17.7          |
# |    map_coverage                    | 27.3          |
# |    new_tiles_revealed              | 0             |
# |    point_reward                    | 0             |
# |    points_earned                   | 5             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 15            |
# |    rule_reward                     | 17.7          |
# |    sap_actions_taken               | 5             |
# |    sap_reward                      | -3            |
# |    static_planner_bonus_sap_reward | 10            |
# |    total_energy                    | 173           |
# |    visited_tiles_count             | 47            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 84            |
# |    iterations                      | 61            |
# |    time_elapsed                    | 11814         |
# |    total_timesteps                 | 999424        |
# | train/                             |               |
# |    approx_kl                       | 0.00019439502 |
# |    clip_fraction                   | 0.000269      |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.857         |
# |    learning_rate                   | 0.000107      |
# |    loss                            | -86           |
# |    n_updates                       | 300           |
# |    policy_gradient_loss            | -0.000484     |
# |    value_loss                      | 0.012         |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 76            |
# |    final_reward                    | 19.3          |
# |    map_coverage                    | 24.8          |
# |    new_tiles_revealed              | 5             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 0             |
# |    rule_reward                     | 19.3          |
# |    sap_actions_taken               | 4             |
# |    sap_reward                      | -2            |
# |    static_planner_bonus_sap_reward | 8             |
# |    total_energy                    | 423           |
# |    visited_tiles_count             | 19            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 84            |
# |    iterations                      | 62            |
# |    time_elapsed                    | 11997         |
# |    total_timesteps                 | 1015808       |
# | train/                             |               |
# |    approx_kl                       | 0.00019062377 |
# |    clip_fraction                   | 0.000354      |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.815         |
# |    learning_rate                   | 0.0001        |
# |    loss                            | -86           |
# |    n_updates                       | 305           |
# |    policy_gradient_loss            | -0.000682     |
# |    value_loss                      | 0.0155        |
# ------------------------------------------------------
