# %%
from luxai_s3.params import EnvParams

from luxai_s3.wrappers import LuxAIS3GymEnv
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.callbacks import CallbackList, CheckpointCallback
import os
import sys
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecNormalize, SubprocVecEnv, DummyVecEnv
import torch

# Add the project root directory to the Python path
sys.path.append(os.path.abspath(".."))
from wrappers.static_planner_wrapper import SB3LuxEnvStaticPlanner
from common.helper import EnhancedTensorboardCallback, make_env, custom_env_check, linear_schedule

# %% [markdown]
# ## Check if the environment is compatible with SB3

# %%
# Create the base environment
base_env = LuxAIS3GymEnv()
# Create environment parameters
env_params = EnvParams(map_type=0, max_steps_in_match=100)

# Apply our wrapper with explicit player_id and opponent strategy
wrapped_env = SB3LuxEnvStaticPlanner(base_env, player_id='player_0', opponent_strategy='random')

# Create the environment
env = make_env(env_params, wrapped_env, seed=367)  # Using a fixed seed for reproducibility

# Print observation space shape
print(f"Observation space: {env.observation_space}")
print(f"Action space: {env.action_space}")

check_env(env)
print("Environment check passed successfully!")
# Out:
# Observation space: Dict('env_cfg_map_height': Box(0, 24, (1,), int32), 'env_cfg_map_width': Box(0, 24, (1,), int32), 'env_cfg_max_steps_in_match': Box(0, 100, (1,), int32), 'env_cfg_unit_move_cost': Box(0, 100, (1,), int32), 'env_cfg_unit_sap_cost': Box(0, 100, (1,), int32), 'env_cfg_unit_sap_range': Box(0, 100, (1,), int32), 'map_features_energy': Box(-1, 20, (24, 24), int8), 'map_features_tile_type': Box(-1, 2, (24, 24), int8), 'match_steps': Box(0, 100, (1,), int32), 'relic_nodes': Box(-1, 23, (6, 2), int32), 'relic_nodes_mask': Box(0, 1, (6,), int8), 'remainingOverageTime': Box(0, 1000, (1,), int32), 'sensor_mask': Box(0, 1, (24, 24), int8), 'steps': Box(0, 100, (1,), int32), 'team_points': Box(0, 1000, (2,), int32), 'team_wins': Box(0, 1000, (2,), int32), 'units_energy': Box(0, 400, (2, 16, 1), int32), 'units_mask': Box(0, 1, (2, 16), int8), 'units_position': Box(-1, 575, (2, 16, 2), int32))
# Action space: MultiDiscrete([6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6])
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: Your observation map_features_energy has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: Your observation map_features_tile_type has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: Your observation relic_nodes has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: Your observation sensor_mask has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:55: UserWarning: It seems that your observation units_energy is an image but its `dtype` is (int32) whereas it has to be `np.uint8`. If your observation is not an image, we recommend you to flatten the observation to have only a 1D vector
#   warnings.warn(
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:63: UserWarning: It seems that your observation space units_energy is an image but the upper and lower bounds are not in [0, 255]. Because the CNN policy normalize automatically the observation you may encounter issue if the values are not in that range.
#   warnings.warn(
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:76: UserWarning: The minimal resolution for an image is 36x36 for the default `CnnPolicy`. You might need to use a custom features extractor cf. https://stable-baselines3.readthedocs.io/en/master/guide/custom_policy.html
#   warnings.warn(
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: Your observation units_mask has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:55: UserWarning: It seems that your observation units_position is an image but its `dtype` is (int32) whereas it has to be `np.uint8`. If your observation is not an image, we recommend you to flatten the observation to have only a 1D vector
#   warnings.warn(
# /opt/anaconda3/envs/inf367_2/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:63: UserWarning: It seems that your observation space units_position is an image but the upper and lower bounds are not in [0, 255]. Because the CNN policy normalize automatically the observation you may encounter issue if the values are not in that range.
#   warnings.warn(
# Environment check passed successfully!

# %% [markdown]
# #### Custom enviorment check 🤖

# %%
# custom_env_check(env, 2)

# %% [markdown]
# ### Train the base PPO model

# %%
models_dir = "../ppo_lux_model_static_planner/"
SAVE_FREQUENCY = 1000

envs = SubprocVecEnv(
    [lambda: make_env(env_params, wrapped_env, seed=i) for i in range(8)]
)
envs = VecNormalize(envs, norm_obs=True, norm_reward=True)
# Create callbacks
enchared_tb_callback = EnhancedTensorboardCallback()
checkpoint_callback = CheckpointCallback(
    save_freq=SAVE_FREQUENCY, save_path=models_dir, name_prefix="ppo_lux_model_static_planner"
)

# Combine callbacks
callbacks = CallbackList([enchared_tb_callback, checkpoint_callback])

mps_device = None
if not torch.backends.mps.is_available():
    if not torch.backends.mps.is_built():
        print(
            "MPS not available because the current PyTorch install was not "
            "built with MPS enabled."
        )
    else:
        print(
            "MPS not available because the current MacOS version is not 12.3+ "
            "and/or you do not have an MPS-enabled device on this machine."
        )
else:
    mps_device = torch.device("mps")

    print("MPS available and enabled.")

# Create PPO model
model = PPO(
    "MultiInputPolicy",
    envs,
    verbose=1,
    learning_rate=linear_schedule(5e-4, 1e-4),
    n_steps=2048,
    batch_size=128,
    n_epochs=5,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    vf_coef=0.25,
    ent_coef=3.0,
    clip_range_vf=0.2,
    tensorboard_log="./ppo_lux_tensorboard/",
    device=mps_device,
    policy_kwargs=dict(net_arch=[512, 256, 128], activation_fn=torch.nn.ReLU),
)

# Train the model with callbacks
model.learn(total_timesteps=1000000, callback=callbacks)

# Save final model
model.save("ppo_lux_model_static_planner")
# Out:
# MPS available and enabled.
# Using mps device
# Logging to ./ppo_lux_tensorboard/PPO_5
# -------------------------------------------------
# | lux/                               |          |
# |    energy_collected                | 8        |
# |    final_reward                    | 1.19     |
# |    map_coverage                    | 8.16     |
# |    new_tiles_revealed              | 6        |
# |    point_reward                    | 0        |
# |    points_earned                   | 0        |
# |    relic_control_streak            | 0        |
# |    relic_point_tiles_found         | 0        |
# |    rule_reward                     | 1.19     |
# |    sap_actions_taken               | 2        |
# |    sap_reward                      | -1       |
# |    static_planner_bonus_sap_reward | 4        |
# |    total_energy                    | 91       |
# |    visited_tiles_count             | 11       |
# |    win_rate                        | 0        |
# | time/                              |          |
# |    fps                             | 95       |
# |    iterations                      | 1        |
# |    time_elapsed                    | 171      |
# |    total_timesteps                 | 16384    |
# -------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 6            |
# |    final_reward                    | 15.1         |
# |    map_coverage                    | 4.86         |
# |    new_tiles_revealed              | 0            |
# |    point_reward                    | 0            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | 15.1         |
# |    sap_actions_taken               | 3            |
# |    sap_reward                      | 0            |
# |    static_planner_bonus_sap_reward | 6            |
# |    total_energy                    | 69           |
# |    visited_tiles_count             | 9            |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 89           |
# |    iterations                      | 2            |
# |    time_elapsed                    | 365          |
# |    total_timesteps                 | 32768        |
# | train/                             |              |
# |    approx_kl                       | 0.0058015436 |
# |    clip_fraction                   | 0.034        |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | -0.14        |
# |    learning_rate                   | 0.000493     |
# |    loss                            | -85.9        |
# |    n_updates                       | 5            |
# |    policy_gradient_loss            | -0.0186      |
# |    value_loss                      | 0.589        |
# -----------------------------------------------------
# ----------------------------------------------------
# | lux/                               |             |
# |    energy_collected                | 4           |
# |    final_reward                    | 21          |
# |    map_coverage                    | 30.7        |
# |    new_tiles_revealed              | 3           |
# |    point_reward                    | 0           |
# |    points_earned                   | 3           |
# |    relic_control_streak            | 0           |
# |    relic_point_tiles_found         | 4           |
# |    rule_reward                     | 21          |
# |    sap_actions_taken               | 2           |
# |    sap_reward                      | 0           |
# |    static_planner_bonus_sap_reward | 4           |
# |    total_energy                    | 39          |
# |    visited_tiles_count             | 24          |
# |    win_rate                        | 0           |
# | time/                              |             |
# |    fps                             | 87          |
# |    iterations                      | 3           |
# |    time_elapsed                    | 559         |
# |    total_timesteps                 | 49152       |
# | train/                             |             |
# |    approx_kl                       | 0.004747367 |
# |    clip_fraction                   | 0.0267      |
# |    clip_range                      | 0.2         |
# |    clip_range_vf                   | 0.2         |
# |    entropy_loss                    | -28.7       |
# |    explained_variance              | 0.386       |
# |    learning_rate                   | 0.000487    |
# |    loss                            | -86         |
# |    n_updates                       | 10          |
# |    policy_gradient_loss            | -0.0133     |
# |    value_loss                      | 0.109       |
# ----------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 9            |
# |    final_reward                    | 5.82         |
# |    map_coverage                    | 11.5         |
# |    new_tiles_revealed              | 3            |
# |    point_reward                    | 0            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | 5.82         |
# |    sap_actions_taken               | 0            |
# |    sap_reward                      | 0            |
# |    static_planner_bonus_sap_reward | 0            |
# |    total_energy                    | 436          |
# |    visited_tiles_count             | 21           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 86           |
# |    iterations                      | 4            |
# |    time_elapsed                    | 753          |
# |    total_timesteps                 | 65536        |
# | train/                             |              |
# |    approx_kl                       | 0.0033470988 |
# |    clip_fraction                   | 0.0257       |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.236        |
# |    learning_rate                   | 0.00048      |
# |    loss                            | -86          |
# |    n_updates                       | 15           |
# |    policy_gradient_loss            | -0.00435     |
# |    value_loss                      | 0.055        |
# -----------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 0            |
# |    final_reward                    | -0.0772      |
# |    map_coverage                    | 24           |
# |    new_tiles_revealed              | 3            |
# |    point_reward                    | 1            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | -0.0772      |
# |    sap_actions_taken               | 4            |
# |    sap_reward                      | -1           |
# |    static_planner_bonus_sap_reward | 8            |
# |    total_energy                    | 62           |
# |    visited_tiles_count             | 43           |
# |    win_rate                        | 1            |
# | time/                              |              |
# |    fps                             | 86           |
# |    iterations                      | 5            |
# |    time_elapsed                    | 946          |
# |    total_timesteps                 | 81920        |
# | train/                             |              |
# |    approx_kl                       | 0.0014450906 |
# |    clip_fraction                   | 0.00573      |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.0428       |
# |    learning_rate                   | 0.000474     |
# |    loss                            | -86          |
# |    n_updates                       | 20           |
# |    policy_gradient_loss            | -0.00383     |
# |    value_loss                      | 0.0248       |
# -----------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 0            |
# |    final_reward                    | -0.257       |
# |    map_coverage                    | 18.4         |
# |    new_tiles_revealed              | 1            |
# |    point_reward                    | 0            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | -0.257       |
# |    sap_actions_taken               | 1            |
# |    sap_reward                      | -1           |
# |    static_planner_bonus_sap_reward | 2            |
# |    total_energy                    | 184          |
# |    visited_tiles_count             | 56           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 86           |
# |    iterations                      | 6            |
# |    time_elapsed                    | 1138         |
# |    total_timesteps                 | 98304        |
# | train/                             |              |
# |    approx_kl                       | 0.0013631799 |
# |    clip_fraction                   | 0.00549      |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.451        |
# |    learning_rate                   | 0.000467     |
# |    loss                            | -86          |
# |    n_updates                       | 25           |
# |    policy_gradient_loss            | -0.00268     |
# |    value_loss                      | 0.00814      |
# -----------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 0            |
# |    final_reward                    | -27.9        |
# |    map_coverage                    | 26.2         |
# |    new_tiles_revealed              | 0            |
# |    point_reward                    | 0            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | -27.9        |
# |    sap_actions_taken               | 4            |
# |    sap_reward                      | -3           |
# |    static_planner_bonus_sap_reward | 8            |
# |    total_energy                    | 0            |
# |    visited_tiles_count             | 22           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 86           |
# |    iterations                      | 7            |
# |    time_elapsed                    | 1332         |
# |    total_timesteps                 | 114688       |
# | train/                             |              |
# |    approx_kl                       | 0.0013265247 |
# |    clip_fraction                   | 0.00435      |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.36         |
# |    learning_rate                   | 0.000461     |
# |    loss                            | -86          |
# |    n_updates                       | 30           |
# |    policy_gradient_loss            | -0.00309     |
# |    value_loss                      | 0.00733      |
# -----------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 87           |
# |    final_reward                    | 1.58         |
# |    map_coverage                    | 18.4         |
# |    new_tiles_revealed              | 6            |
# |    point_reward                    | 0            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | 1.58         |
# |    sap_actions_taken               | 3            |
# |    sap_reward                      | 0            |
# |    static_planner_bonus_sap_reward | 6            |
# |    total_energy                    | 494          |
# |    visited_tiles_count             | 52           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 85           |
# |    iterations                      | 8            |
# |    time_elapsed                    | 1525         |
# |    total_timesteps                 | 131072       |
# | train/                             |              |
# |    approx_kl                       | 0.0008526681 |
# |    clip_fraction                   | 0.00266      |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.438        |
# |    learning_rate                   | 0.000454     |
# |    loss                            | -86          |
# |    n_updates                       | 35           |
# |    policy_gradient_loss            | -0.00155     |
# |    value_loss                      | 0.00284      |
# -----------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 0             |
# |    final_reward                    | 14.4          |
# |    map_coverage                    | 33.9          |
# |    new_tiles_revealed              | 0             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 0             |
# |    rule_reward                     | 14.4          |
# |    sap_actions_taken               | 2             |
# |    sap_reward                      | -1            |
# |    static_planner_bonus_sap_reward | 4             |
# |    total_energy                    | 143           |
# |    visited_tiles_count             | 45            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 85            |
# |    iterations                      | 9             |
# |    time_elapsed                    | 1723          |
# |    total_timesteps                 | 147456        |
# | train/                             |               |
# |    approx_kl                       | 0.00079414155 |
# |    clip_fraction                   | 0.00234       |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.42          |
# |    learning_rate                   | 0.000448      |
# |    loss                            | -86           |
# |    n_updates                       | 40            |
# |    policy_gradient_loss            | -0.00137      |
# |    value_loss                      | 0.00642       |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 5             |
# |    final_reward                    | 18.8          |
# |    map_coverage                    | 23.1          |
# |    new_tiles_revealed              | 1             |
# |    point_reward                    | 1             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 7             |
# |    rule_reward                     | 18.8          |
# |    sap_actions_taken               | 2             |
# |    sap_reward                      | -2            |
# |    static_planner_bonus_sap_reward | 4             |
# |    total_energy                    | 297           |
# |    visited_tiles_count             | 63            |
# |    win_rate                        | 0.5           |
# | time/                              |               |
# |    fps                             | 85            |
# |    iterations                      | 10            |
# |    time_elapsed                    | 1917          |
# |    total_timesteps                 | 163840        |
# | train/                             |               |
# |    approx_kl                       | 0.00081989076 |
# |    clip_fraction                   | 0.00229       |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.415         |
# |    learning_rate                   | 0.000441      |
# |    loss                            | -86           |
# |    n_updates                       | 45            |
# |    policy_gradient_loss            | -0.000879     |
# |    value_loss                      | 0.0381        |
# ------------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 1            |
# |    final_reward                    | -36.7        |
# |    map_coverage                    | 14.4         |
# |    new_tiles_revealed              | 0            |
# |    point_reward                    | 2            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 32           |
# |    rule_reward                     | -36.7        |
# |    sap_actions_taken               | 2            |
# |    sap_reward                      | -2           |
# |    static_planner_bonus_sap_reward | 4            |
# |    total_energy                    | 189          |
# |    visited_tiles_count             | 36           |
# |    win_rate                        | 0.667        |
# | time/                              |              |
# |    fps                             | 85           |
# |    iterations                      | 11           |
# |    time_elapsed                    | 2112         |
# |    total_timesteps                 | 180224       |
# | train/                             |              |
# |    approx_kl                       | 0.0009607894 |
# |    clip_fraction                   | 0.00282      |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.645        |
# |    learning_rate                   | 0.000434     |
# |    loss                            | -86          |
# |    n_updates                       | 50           |
# |    policy_gradient_loss            | -0.00176     |
# |    value_loss                      | 0.00324      |
# -----------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 0            |
# |    final_reward                    | -25.5        |
# |    map_coverage                    | 23.6         |
# |    new_tiles_revealed              | 6            |
# |    point_reward                    | 1            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | -25.5        |
# |    sap_actions_taken               | 2            |
# |    sap_reward                      | -2           |
# |    static_planner_bonus_sap_reward | 4            |
# |    total_energy                    | 185          |
# |    visited_tiles_count             | 53           |
# |    win_rate                        | 0.333        |
# | time/                              |              |
# |    fps                             | 85           |
# |    iterations                      | 12           |
# |    time_elapsed                    | 2306         |
# |    total_timesteps                 | 196608       |
# | train/                             |              |
# |    approx_kl                       | 0.0011194821 |
# |    clip_fraction                   | 0.003        |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.58         |
# |    learning_rate                   | 0.000428     |
# |    loss                            | -86          |
# |    n_updates                       | 55           |
# |    policy_gradient_loss            | -0.00212     |
# |    value_loss                      | 0.0257       |
# -----------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 0             |
# |    final_reward                    | 19.4          |
# |    map_coverage                    | 25.2          |
# |    new_tiles_revealed              | 3             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 3             |
# |    rule_reward                     | 19.4          |
# |    sap_actions_taken               | 3             |
# |    sap_reward                      | -2            |
# |    static_planner_bonus_sap_reward | 6             |
# |    total_energy                    | 603           |
# |    visited_tiles_count             | 50            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 85            |
# |    iterations                      | 13            |
# |    time_elapsed                    | 2500          |
# |    total_timesteps                 | 212992        |
# | train/                             |               |
# |    approx_kl                       | 0.00080035627 |
# |    clip_fraction                   | 0.00151       |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.595         |
# |    learning_rate                   | 0.000421      |
# |    loss                            | -86           |
# |    n_updates                       | 60            |
# |    policy_gradient_loss            | -0.00124      |
# |    value_loss                      | 0.0206        |
# ------------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 4            |
# |    final_reward                    | 71.2         |
# |    map_coverage                    | 18.8         |
# |    new_tiles_revealed              | 2            |
# |    point_reward                    | 0            |
# |    points_earned                   | 2            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 18           |
# |    rule_reward                     | 71.2         |
# |    sap_actions_taken               | 0            |
# |    sap_reward                      | 0            |
# |    static_planner_bonus_sap_reward | 0            |
# |    total_energy                    | 136          |
# |    visited_tiles_count             | 76           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 85           |
# |    iterations                      | 14           |
# |    time_elapsed                    | 2695         |
# |    total_timesteps                 | 229376       |
# | train/                             |              |
# |    approx_kl                       | 0.0006072012 |
# |    clip_fraction                   | 0.0005       |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.613        |
# |    learning_rate                   | 0.000415     |
# |    loss                            | -86          |
# |    n_updates                       | 65           |
# |    policy_gradient_loss            | -0.00105     |
# |    value_loss                      | 0.0101       |
# -----------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 56            |
# |    final_reward                    | -24.7         |
# |    map_coverage                    | 26.7          |
# |    new_tiles_revealed              | 0             |
# |    point_reward                    | 2             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 60            |
# |    rule_reward                     | -24.7         |
# |    sap_actions_taken               | 5             |
# |    sap_reward                      | -5            |
# |    static_planner_bonus_sap_reward | 10            |
# |    total_energy                    | 259           |
# |    visited_tiles_count             | 95            |
# |    win_rate                        | 0.5           |
# | time/                              |               |
# |    fps                             | 85            |
# |    iterations                      | 15            |
# |    time_elapsed                    | 2889          |
# |    total_timesteps                 | 245760        |
# | train/                             |               |
# |    approx_kl                       | 0.00070005807 |
# |    clip_fraction                   | 0.000818      |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.513         |
# |    learning_rate                   | 0.000408      |
# |    loss                            | -86           |
# |    n_updates                       | 70            |
# |    policy_gradient_loss            | -0.000688     |
# |    value_loss                      | 0.0582        |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 0             |
# |    final_reward                    | 69.9          |
# |    map_coverage                    | 19.8          |
# |    new_tiles_revealed              | 1             |
# |    point_reward                    | 2             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 42            |
# |    rule_reward                     | 69.9          |
# |    sap_actions_taken               | 1             |
# |    sap_reward                      | -1            |
# |    static_planner_bonus_sap_reward | 2             |
# |    total_energy                    | 715           |
# |    visited_tiles_count             | 50            |
# |    win_rate                        | 0.5           |
# | time/                              |               |
# |    fps                             | 84            |
# |    iterations                      | 16            |
# |    time_elapsed                    | 3084          |
# |    total_timesteps                 | 262144        |
# | train/                             |               |
# |    approx_kl                       | 0.00051195396 |
# |    clip_fraction                   | 0             |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.47          |
# |    learning_rate                   | 0.000402      |
# |    loss                            | -86           |
# |    n_updates                       | 75            |
# |    policy_gradient_loss            | -0.000559     |
# |    value_loss                      | 0.102         |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 0             |
# |    final_reward                    | 84.6          |
# |    map_coverage                    | 20.1          |
# |    new_tiles_revealed              | 8             |
# |    point_reward                    | 0             |
# |    points_earned                   | 2             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 37            |
# |    rule_reward                     | 84.6          |
# |    sap_actions_taken               | 3             |
# |    sap_reward                      | -3            |
# |    static_planner_bonus_sap_reward | 6             |
# |    total_energy                    | 119           |
# |    visited_tiles_count             | 60            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 84            |
# |    iterations                      | 17            |
# |    time_elapsed                    | 3278          |
# |    total_timesteps                 | 278528        |
# | train/                             |               |
# |    approx_kl                       | 0.00056123745 |
# |    clip_fraction                   | 0.000464      |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.582         |
# |    learning_rate                   | 0.000395      |
# |    loss                            | -86           |
# |    n_updates                       | 80            |
# |    policy_gradient_loss            | -0.00101      |
# |    value_loss                      | 0.0331        |
# ------------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 0            |
# |    final_reward                    | 31.2         |
# |    map_coverage                    | 20.1         |
# |    new_tiles_revealed              | 1            |
# |    point_reward                    | 1            |
# |    points_earned                   | 2            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 32           |
# |    rule_reward                     | 31.2         |
# |    sap_actions_taken               | 5            |
# |    sap_reward                      | -5           |
# |    static_planner_bonus_sap_reward | 10           |
# |    total_energy                    | 275          |
# |    visited_tiles_count             | 90           |
# |    win_rate                        | 0.25         |
# | time/                              |              |
# |    fps                             | 84           |
# |    iterations                      | 18           |
# |    time_elapsed                    | 3472         |
# |    total_timesteps                 | 294912       |
# | train/                             |              |
# |    approx_kl                       | 0.0007960729 |
# |    clip_fraction                   | 0.000171     |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.689        |
# |    learning_rate                   | 0.000389     |
# |    loss                            | -86          |
# |    n_updates                       | 85           |
# |    policy_gradient_loss            | -0.000926    |
# |    value_loss                      | 0.0188       |
# -----------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 0            |
# |    final_reward                    | 0.969        |
# |    map_coverage                    | 6.94         |
# |    new_tiles_revealed              | 0            |
# |    point_reward                    | 0            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | 0.969        |
# |    sap_actions_taken               | 2            |
# |    sap_reward                      | 0            |
# |    static_planner_bonus_sap_reward | 4            |
# |    total_energy                    | 23           |
# |    visited_tiles_count             | 8            |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 84           |
# |    iterations                      | 19           |
# |    time_elapsed                    | 3666         |
# |    total_timesteps                 | 311296       |
# | train/                             |              |
# |    approx_kl                       | 0.0005835171 |
# |    clip_fraction                   | 0            |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.677        |
# |    learning_rate                   | 0.000382     |
# |    loss                            | -86          |
# |    n_updates                       | 90           |
# |    policy_gradient_loss            | -0.000838    |
# |    value_loss                      | 0.038        |
# -----------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 6             |
# |    final_reward                    | 0.131         |
# |    map_coverage                    | 13            |
# |    new_tiles_revealed              | 0             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 0             |
# |    rule_reward                     | 0.131         |
# |    sap_actions_taken               | 2             |
# |    sap_reward                      | 0             |
# |    static_planner_bonus_sap_reward | 4             |
# |    total_energy                    | 65            |
# |    visited_tiles_count             | 15            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 84            |
# |    iterations                      | 20            |
# |    time_elapsed                    | 3861          |
# |    total_timesteps                 | 327680        |
# | train/                             |               |
# |    approx_kl                       | 0.00058999704 |
# |    clip_fraction                   | 0.000378      |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.704         |
# |    learning_rate                   | 0.000375      |
# |    loss                            | -86           |
# |    n_updates                       | 95            |
# |    policy_gradient_loss            | -0.000684     |
# |    value_loss                      | 0.141         |
# ------------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 15           |
# |    final_reward                    | 4.88         |
# |    map_coverage                    | 12.3         |
# |    new_tiles_revealed              | 3            |
# |    point_reward                    | 0            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | 4.88         |
# |    sap_actions_taken               | 2            |
# |    sap_reward                      | -1           |
# |    static_planner_bonus_sap_reward | 4            |
# |    total_energy                    | 200          |
# |    visited_tiles_count             | 32           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 84           |
# |    iterations                      | 21           |
# |    time_elapsed                    | 4057         |
# |    total_timesteps                 | 344064       |
# | train/                             |              |
# |    approx_kl                       | 0.0005775661 |
# |    clip_fraction                   | 0            |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.59         |
# |    learning_rate                   | 0.000369     |
# |    loss                            | -85.9        |
# |    n_updates                       | 100          |
# |    policy_gradient_loss            | -0.000978    |
# |    value_loss                      | 0.131        |
# -----------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 76           |
# |    final_reward                    | -5.89        |
# |    map_coverage                    | 26.7         |
# |    new_tiles_revealed              | 0            |
# |    point_reward                    | 1            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 35           |
# |    rule_reward                     | -5.89        |
# |    sap_actions_taken               | 3            |
# |    sap_reward                      | -1           |
# |    static_planner_bonus_sap_reward | 6            |
# |    total_energy                    | 253          |
# |    visited_tiles_count             | 42           |
# |    win_rate                        | 1            |
# | time/                              |              |
# |    fps                             | 84           |
# |    iterations                      | 22           |
# |    time_elapsed                    | 4254         |
# |    total_timesteps                 | 360448       |
# | train/                             |              |
# |    approx_kl                       | 0.0006366592 |
# |    clip_fraction                   | 0            |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.686        |
# |    learning_rate                   | 0.000362     |
# |    loss                            | -86          |
# |    n_updates                       | 105          |
# |    policy_gradient_loss            | -0.0013      |
# |    value_loss                      | 0.0244       |
# -----------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 0            |
# |    final_reward                    | 0.732        |
# |    map_coverage                    | 14.8         |
# |    new_tiles_revealed              | 2            |
# |    point_reward                    | 0            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | 0.732        |
# |    sap_actions_taken               | 2            |
# |    sap_reward                      | 0            |
# |    static_planner_bonus_sap_reward | 4            |
# |    total_energy                    | 226          |
# |    visited_tiles_count             | 32           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 84           |
# |    iterations                      | 23           |
# |    time_elapsed                    | 4450         |
# |    total_timesteps                 | 376832       |
# | train/                             |              |
# |    approx_kl                       | 0.0006028997 |
# |    clip_fraction                   | 1.22e-05     |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.744        |
# |    learning_rate                   | 0.000356     |
# |    loss                            | -86          |
# |    n_updates                       | 110          |
# |    policy_gradient_loss            | -0.000904    |
# |    value_loss                      | 0.0257       |
# -----------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 0             |
# |    final_reward                    | 89.3          |
# |    map_coverage                    | 22.9          |
# |    new_tiles_revealed              | 0             |
# |    point_reward                    | 0             |
# |    points_earned                   | 36            |
# |    relic_control_streak            | 18            |
# |    relic_point_tiles_found         | 12            |
# |    rule_reward                     | 89.3          |
# |    sap_actions_taken               | 3             |
# |    sap_reward                      | -2            |
# |    static_planner_bonus_sap_reward | 6             |
# |    total_energy                    | 53            |
# |    visited_tiles_count             | 36            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 84            |
# |    iterations                      | 24            |
# |    time_elapsed                    | 4646          |
# |    total_timesteps                 | 393216        |
# | train/                             |               |
# |    approx_kl                       | 0.00065454526 |
# |    clip_fraction                   | 0             |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.787         |
# |    learning_rate                   | 0.000349      |
# |    loss                            | -86           |
# |    n_updates                       | 115           |
# |    policy_gradient_loss            | -0.00107      |
# |    value_loss                      | 0.0349        |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 0             |
# |    final_reward                    | 16.6          |
# |    map_coverage                    | 18.6          |
# |    new_tiles_revealed              | 14            |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 0             |
# |    rule_reward                     | 16.6          |
# |    sap_actions_taken               | 2             |
# |    sap_reward                      | -2            |
# |    static_planner_bonus_sap_reward | 4             |
# |    total_energy                    | 142           |
# |    visited_tiles_count             | 69            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 84            |
# |    iterations                      | 25            |
# |    time_elapsed                    | 4844          |
# |    total_timesteps                 | 409600        |
# | train/                             |               |
# |    approx_kl                       | 0.00058358896 |
# |    clip_fraction                   | 0             |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.847         |
# |    learning_rate                   | 0.000343      |
# |    loss                            | -86           |
# |    n_updates                       | 120           |
# |    policy_gradient_loss            | -0.000926     |
# |    value_loss                      | 0.0884        |
# ------------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 43           |
# |    final_reward                    | 197          |
# |    map_coverage                    | 27.8         |
# |    new_tiles_revealed              | 5            |
# |    point_reward                    | 0            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | 197          |
# |    sap_actions_taken               | 5            |
# |    sap_reward                      | 210          |
# |    static_planner_bonus_sap_reward | 10           |
# |    total_energy                    | 720          |
# |    visited_tiles_count             | 58           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 84           |
# |    iterations                      | 26           |
# ...
# |    approx_kl                       | 0.00024942006 |
# |    clip_fraction                   | 0             |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.743         |
# |    learning_rate                   | 0.000153      |
# |    loss                            | -86           |
# |    n_updates                       | 265           |
# |    policy_gradient_loss            | -0.000537     |
# |    value_loss                      | 0.00861       |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 0             |
# |    final_reward                    | 1.08          |
# |    map_coverage                    | 5.56          |
# |    new_tiles_revealed              | 3             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 0             |
# |    rule_reward                     | 1.08          |
# |    sap_actions_taken               | 3             |
# |    sap_reward                      | 0             |
# |    static_planner_bonus_sap_reward | 6             |
# |    total_energy                    | 0             |
# |    visited_tiles_count             | 2             |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 84            |
# |    iterations                      | 55            |
# |    time_elapsed                    | 10704         |
# |    total_timesteps                 | 901120        |
# | train/                             |               |
# |    approx_kl                       | 0.00027983403 |
# |    clip_fraction                   | 0             |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.743         |
# |    learning_rate                   | 0.000146      |
# |    loss                            | -86           |
# |    n_updates                       | 270           |
# |    policy_gradient_loss            | -0.000755     |
# |    value_loss                      | 0.047         |
# ------------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 0            |
# |    final_reward                    | -2.85        |
# |    map_coverage                    | 9.03         |
# |    new_tiles_revealed              | 0            |
# |    point_reward                    | 0            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | -2.85        |
# |    sap_actions_taken               | 5            |
# |    sap_reward                      | -3           |
# |    static_planner_bonus_sap_reward | 10           |
# |    total_energy                    | 10           |
# |    visited_tiles_count             | 10           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 84           |
# |    iterations                      | 56           |
# |    time_elapsed                    | 10895        |
# |    total_timesteps                 | 917504       |
# | train/                             |              |
# |    approx_kl                       | 0.0002669858 |
# |    clip_fraction                   | 0            |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.836        |
# |    learning_rate                   | 0.00014      |
# |    loss                            | -86          |
# |    n_updates                       | 275          |
# |    policy_gradient_loss            | -0.000779    |
# |    value_loss                      | 0.0942       |
# -----------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 4             |
# |    final_reward                    | 1.19          |
# |    map_coverage                    | 21.5          |
# |    new_tiles_revealed              | 4             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 0             |
# |    rule_reward                     | 1.19          |
# |    sap_actions_taken               | 0             |
# |    sap_reward                      | 0             |
# |    static_planner_bonus_sap_reward | 0             |
# |    total_energy                    | 29            |
# |    visited_tiles_count             | 39            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 84            |
# |    iterations                      | 57            |
# |    time_elapsed                    | 11090         |
# |    total_timesteps                 | 933888        |
# | train/                             |               |
# |    approx_kl                       | 0.00023291406 |
# |    clip_fraction                   | 0             |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.814         |
# |    learning_rate                   | 0.000133      |
# |    loss                            | -86           |
# |    n_updates                       | 280           |
# |    policy_gradient_loss            | -0.000583     |
# |    value_loss                      | 0.0157        |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 8             |
# |    final_reward                    | -12.8         |
# |    map_coverage                    | 12.8          |
# |    new_tiles_revealed              | 0             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 0             |
# |    rule_reward                     | -12.8         |
# |    sap_actions_taken               | 5             |
# |    sap_reward                      | -3            |
# |    static_planner_bonus_sap_reward | 10            |
# |    total_energy                    | 339           |
# |    visited_tiles_count             | 32            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 84            |
# |    iterations                      | 58            |
# |    time_elapsed                    | 11289         |
# |    total_timesteps                 | 950272        |
# | train/                             |               |
# |    approx_kl                       | 0.00013936168 |
# |    clip_fraction                   | 0             |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.838         |
# |    learning_rate                   | 0.000126      |
# |    loss                            | -86           |
# |    n_updates                       | 285           |
# |    policy_gradient_loss            | -0.000347     |
# |    value_loss                      | 0.0312        |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 29            |
# |    final_reward                    | -6.84         |
# |    map_coverage                    | 16.3          |
# |    new_tiles_revealed              | 0             |
# |    point_reward                    | 0             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 0             |
# |    rule_reward                     | -6.84         |
# |    sap_actions_taken               | 5             |
# |    sap_reward                      | -2            |
# |    static_planner_bonus_sap_reward | 10            |
# |    total_energy                    | 97            |
# |    visited_tiles_count             | 23            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 84            |
# |    iterations                      | 59            |
# |    time_elapsed                    | 11490         |
# |    total_timesteps                 | 966656        |
# | train/                             |               |
# |    approx_kl                       | 0.00020915402 |
# |    clip_fraction                   | 0             |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.819         |
# |    learning_rate                   | 0.00012       |
# |    loss                            | -86           |
# |    n_updates                       | 290           |
# |    policy_gradient_loss            | -0.000564     |
# |    value_loss                      | 0.0265        |
# ------------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 9             |
# |    final_reward                    | 91.8          |
# |    map_coverage                    | 27.3          |
# |    new_tiles_revealed              | 1             |
# |    point_reward                    | 0             |
# |    points_earned                   | 7             |
# |    relic_control_streak            | 2             |
# |    relic_point_tiles_found         | 31            |
# |    rule_reward                     | 91.8          |
# |    sap_actions_taken               | 0             |
# |    sap_reward                      | 0             |
# |    static_planner_bonus_sap_reward | 0             |
# |    total_energy                    | 252           |
# |    visited_tiles_count             | 53            |
# |    win_rate                        | 0             |
# | time/                              |               |
# |    fps                             | 84            |
# |    iterations                      | 60            |
# |    time_elapsed                    | 11691         |
# |    total_timesteps                 | 983040        |
# | train/                             |               |
# |    approx_kl                       | 0.00016062686 |
# |    clip_fraction                   | 0             |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.727         |
# |    learning_rate                   | 0.000113      |
# |    loss                            | -86           |
# |    n_updates                       | 295           |
# |    policy_gradient_loss            | -0.000404     |
# |    value_loss                      | 0.0119        |
# ------------------------------------------------------
# -----------------------------------------------------
# | lux/                               |              |
# |    energy_collected                | 0            |
# |    final_reward                    | 14.4         |
# |    map_coverage                    | 23.8         |
# |    new_tiles_revealed              | 0            |
# |    point_reward                    | 0            |
# |    points_earned                   | 0            |
# |    relic_control_streak            | 0            |
# |    relic_point_tiles_found         | 0            |
# |    rule_reward                     | 14.4         |
# |    sap_actions_taken               | 3            |
# |    sap_reward                      | -1           |
# |    static_planner_bonus_sap_reward | 6            |
# |    total_energy                    | 62           |
# |    visited_tiles_count             | 41           |
# |    win_rate                        | 0            |
# | time/                              |              |
# |    fps                             | 84           |
# |    iterations                      | 61           |
# |    time_elapsed                    | 11890        |
# |    total_timesteps                 | 999424       |
# | train/                             |              |
# |    approx_kl                       | 0.0001134153 |
# |    clip_fraction                   | 0            |
# |    clip_range                      | 0.2          |
# |    clip_range_vf                   | 0.2          |
# |    entropy_loss                    | -28.7        |
# |    explained_variance              | 0.827        |
# |    learning_rate                   | 0.000107     |
# |    loss                            | -86          |
# |    n_updates                       | 300          |
# |    policy_gradient_loss            | -0.000343    |
# |    value_loss                      | 0.0122       |
# -----------------------------------------------------
# ------------------------------------------------------
# | lux/                               |               |
# |    energy_collected                | 110           |
# |    final_reward                    | -12.8         |
# |    map_coverage                    | 16.1          |
# |    new_tiles_revealed              | 0             |
# |    point_reward                    | 1             |
# |    points_earned                   | 0             |
# |    relic_control_streak            | 0             |
# |    relic_point_tiles_found         | 12            |
# |    rule_reward                     | -12.8         |
# |    sap_actions_taken               | 4             |
# |    sap_reward                      | -3            |
# |    static_planner_bonus_sap_reward | 8             |
# |    total_energy                    | 469           |
# |    visited_tiles_count             | 43            |
# |    win_rate                        | 0.5           |
# | time/                              |               |
# |    fps                             | 84            |
# |    iterations                      | 62            |
# |    time_elapsed                    | 12088         |
# |    total_timesteps                 | 1015808       |
# | train/                             |               |
# |    approx_kl                       | 0.00016795732 |
# |    clip_fraction                   | 0             |
# |    clip_range                      | 0.2           |
# |    clip_range_vf                   | 0.2           |
# |    entropy_loss                    | -28.7         |
# |    explained_variance              | 0.859         |
# |    learning_rate                   | 0.0001        |
# |    loss                            | -86           |
# |    n_updates                       | 305           |
# |    policy_gradient_loss            | -0.000596     |
# |    value_loss                      | 0.0105        |
# ------------------------------------------------------
