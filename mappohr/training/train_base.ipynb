# %%
from luxai_s3.params import EnvParams

from luxai_s3.wrappers import LuxAIS3GymEnv
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.callbacks import CallbackList, CheckpointCallback
import os
import sys
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecNormalize, SubprocVecEnv, DummyVecEnv
import torch
# Add the project root directory to the Python path
sys.path.append(os.path.abspath(".."))
from wrappers.base_wrapper import SB3LuxEnvBase
from common.helper import EnhancedTensorboardCallback, make_env, custom_env_check, linear_schedule

# %% [markdown]
# ## Check if the environment is compatible with SB3

# %%
# Create the base environment
base_env = LuxAIS3GymEnv()
# Create environment parameters
env_params = EnvParams(map_type=0, max_steps_in_match=100)

# Apply our wrapper with explicit player_id and opponent strategy
wrapped_env = SB3LuxEnvBase(base_env, player_id='player_0', opponent_strategy='random')

# Create the environment
env = make_env(env_params, wrapped_env, seed=367)  # Using a fixed seed for reproducibility

# Print observation space shape
print(f"Observation space: {env.observation_space}")
print(f"Action space: {env.action_space}")

check_env(env)
print("Environment check passed successfully!")
# Out:
# Observation space: Dict('env_cfg_map_height': Box(0, 24, (1,), int32), 'env_cfg_map_width': Box(0, 24, (1,), int32), 'env_cfg_max_steps_in_match': Box(0, 100, (1,), int32), 'env_cfg_unit_move_cost': Box(0, 100, (1,), int32), 'env_cfg_unit_sap_cost': Box(0, 100, (1,), int32), 'env_cfg_unit_sap_range': Box(0, 100, (1,), int32), 'map_features_energy': Box(-1, 20, (24, 24), int8), 'map_features_tile_type': Box(-1, 2, (24, 24), int8), 'match_steps': Box(0, 100, (1,), int32), 'relic_nodes': Box(-1, 23, (6, 2), int32), 'relic_nodes_mask': Box(0, 1, (6,), int8), 'remainingOverageTime': Box(0, 1000, (1,), int32), 'sensor_mask': Box(0, 1, (24, 24), int8), 'steps': Box(0, 100, (1,), int32), 'team_points': Box(0, 1000, (2,), int32), 'team_wins': Box(0, 1000, (2,), int32), 'units_energy': Box(0, 400, (2, 16, 1), int32), 'units_mask': Box(0, 1, (2, 16), int8), 'units_position': Box(-1, 575, (2, 16, 2), int32))
# Action space: MultiDiscrete([6 6 6 6 6 6 6 6 6 6 6 6 6 6 6 6])
# /opt/anaconda3/envs/inf367/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: Your observation map_features_energy has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /opt/anaconda3/envs/inf367/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: Your observation map_features_tile_type has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /opt/anaconda3/envs/inf367/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: Your observation relic_nodes has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /opt/anaconda3/envs/inf367/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: Your observation sensor_mask has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /opt/anaconda3/envs/inf367/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:55: UserWarning: It seems that your observation units_energy is an image but its `dtype` is (int32) whereas it has to be `np.uint8`. If your observation is not an image, we recommend you to flatten the observation to have only a 1D vector
#   warnings.warn(
# /opt/anaconda3/envs/inf367/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:63: UserWarning: It seems that your observation space units_energy is an image but the upper and lower bounds are not in [0, 255]. Because the CNN policy normalize automatically the observation you may encounter issue if the values are not in that range.
#   warnings.warn(
# /opt/anaconda3/envs/inf367/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:76: UserWarning: The minimal resolution for an image is 36x36 for the default `CnnPolicy`. You might need to use a custom features extractor cf. https://stable-baselines3.readthedocs.io/en/master/guide/custom_policy.html
#   warnings.warn(
# /opt/anaconda3/envs/inf367/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: Your observation units_mask has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# /opt/anaconda3/envs/inf367/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:55: UserWarning: It seems that your observation units_position is an image but its `dtype` is (int32) whereas it has to be `np.uint8`. If your observation is not an image, we recommend you to flatten the observation to have only a 1D vector
#   warnings.warn(
# /opt/anaconda3/envs/inf367/lib/python3.11/site-packages/stable_baselines3/common/env_checker.py:63: UserWarning: It seems that your observation space units_position is an image but the upper and lower bounds are not in [0, 255]. Because the CNN policy normalize automatically the observation you may encounter issue if the values are not in that range.
#   warnings.warn(
# Environment check passed successfully!

# %% [markdown]
# #### Custom enviorment check 🤖

# %%
# custom_env_check(env, 2)

# %% [markdown]
# ### Train the base PPO model

# %%
models_dir = "../ppo_lux_model_base/"
SAVE_FREQUENCY = 1000

envs = SubprocVecEnv(
    [lambda: make_env(env_params, wrapped_env, seed=i) for i in range(8)]
)
envs = VecNormalize(envs, norm_obs=True, norm_reward=True)

# Create callbacks
enchared_tb_callback = EnhancedTensorboardCallback()
checkpoint_callback = CheckpointCallback(
    save_freq=SAVE_FREQUENCY, save_path=models_dir, name_prefix="ppo_lux_model_base"
)

# Combine callbacks
callbacks = CallbackList([enchared_tb_callback, checkpoint_callback])

mps_device = None
if not torch.backends.mps.is_available():
    if not torch.backends.mps.is_built():
        print(
            "MPS not available because the current PyTorch install was not "
            "built with MPS enabled."
        )
    else:
        print(
            "MPS not available because the current MacOS version is not 12.3+ "
            "and/or you do not have an MPS-enabled device on this machine."
        )
else:
    mps_device = torch.device("mps")

    print("MPS available and enabled.")

# Create PPO model
model = PPO(
    "MultiInputPolicy",
    envs,
    verbose=1,
    learning_rate=linear_schedule(5e-4, 1e-4),
    n_steps=2048,
    batch_size=128,
    n_epochs=5,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    vf_coef=0.25,
    ent_coef=3.0,
    clip_range_vf=0.2,
    tensorboard_log="./ppo_lux_tensorboard/",
    device=mps_device,
    policy_kwargs=dict(net_arch=[512, 256, 128], activation_fn=torch.nn.ReLU),
)

# Train the model with callbacks
model.learn(total_timesteps=1000000, callback=callbacks)

# Save final model
model.save("ppo_lux_model_base")
# Out:
# MPS available and enabled.
# Using mps device
# Logging to ./ppo_lux_tensorboard/PPO_4
# -----------------------------------------
# | lux/                       |          |
# |    energy_collected        | 0        |
# |    final_reward            | 5.98     |
# |    map_coverage            | 5.9      |
# |    new_tiles_revealed      | 5        |
# |    point_reward            | 0        |
# |    points_earned           | 0        |
# |    relic_control_streak    | 0        |
# |    relic_point_tiles_found | 0        |
# |    rule_reward             | 5.98     |
# |    sap_actions_taken       | 4        |
# |    sap_reward              | -1       |
# |    total_energy            | 29       |
# |    visited_tiles_count     | 14       |
# |    win_rate                | 0        |
# | time/                      |          |
# |    fps                     | 107      |
# |    iterations              | 1        |
# |    time_elapsed            | 152      |
# |    total_timesteps         | 16384    |
# -----------------------------------------
# --------------------------------------------
# | lux/                       |             |
# |    energy_collected        | 0           |
# |    final_reward            | 20.5        |
# |    map_coverage            | 6.42        |
# |    new_tiles_revealed      | 1           |
# |    point_reward            | 0           |
# |    points_earned           | 0           |
# |    relic_control_streak    | 0           |
# |    relic_point_tiles_found | 0           |
# |    rule_reward             | 20.5        |
# |    sap_actions_taken       | 1           |
# |    sap_reward              | 0           |
# |    total_energy            | 214         |
# |    visited_tiles_count     | 18          |
# |    win_rate                | 0           |
# | time/                      |             |
# |    fps                     | 100         |
# |    iterations              | 2           |
# |    time_elapsed            | 326         |
# |    total_timesteps         | 32768       |
# | train/                     |             |
# |    approx_kl               | 0.006040013 |
# |    clip_fraction           | 0.0332      |
# |    clip_range              | 0.2         |
# |    clip_range_vf           | 0.2         |
# |    entropy_loss            | -28.7       |
# |    explained_variance      | -0.114      |
# |    learning_rate           | 0.000493    |
# |    loss                    | -85.9       |
# |    n_updates               | 5           |
# |    policy_gradient_loss    | -0.0195     |
# |    value_loss              | 0.449       |
# --------------------------------------------
# --------------------------------------------
# | lux/                       |             |
# |    energy_collected        | 19          |
# |    final_reward            | 13.3        |
# |    map_coverage            | 29.3        |
# |    new_tiles_revealed      | 0           |
# |    point_reward            | 0           |
# |    points_earned           | 0           |
# |    relic_control_streak    | 0           |
# |    relic_point_tiles_found | 0           |
# |    rule_reward             | 13.3        |
# |    sap_actions_taken       | 4           |
# |    sap_reward              | -2          |
# |    total_energy            | 131         |
# |    visited_tiles_count     | 42          |
# |    win_rate                | 0           |
# | time/                      |             |
# |    fps                     | 97          |
# |    iterations              | 3           |
# |    time_elapsed            | 502         |
# |    total_timesteps         | 49152       |
# | train/                     |             |
# |    approx_kl               | 0.003956033 |
# |    clip_fraction           | 0.021       |
# |    clip_range              | 0.2         |
# |    clip_range_vf           | 0.2         |
# |    entropy_loss            | -28.7       |
# |    explained_variance      | 0.446       |
# |    learning_rate           | 0.000487    |
# |    loss                    | -86         |
# |    n_updates               | 10          |
# |    policy_gradient_loss    | -0.00912    |
# |    value_loss              | 0.0671      |
# --------------------------------------------
# --------------------------------------------
# | lux/                       |             |
# |    energy_collected        | 10          |
# |    final_reward            | 0.807       |
# |    map_coverage            | 10.2        |
# |    new_tiles_revealed      | 3           |
# |    point_reward            | 0           |
# |    points_earned           | 0           |
# |    relic_control_streak    | 0           |
# |    relic_point_tiles_found | 0           |
# |    rule_reward             | 0.807       |
# |    sap_actions_taken       | 2           |
# |    sap_reward              | 0           |
# |    total_energy            | 471         |
# |    visited_tiles_count     | 22          |
# |    win_rate                | 0           |
# | time/                      |             |
# |    fps                     | 96          |
# |    iterations              | 4           |
# |    time_elapsed            | 679         |
# |    total_timesteps         | 65536       |
# | train/                     |             |
# |    approx_kl               | 0.003250443 |
# |    clip_fraction           | 0.0209      |
# |    clip_range              | 0.2         |
# |    clip_range_vf           | 0.2         |
# |    entropy_loss            | -28.7       |
# |    explained_variance      | -0.311      |
# |    learning_rate           | 0.00048     |
# |    loss                    | -86         |
# |    n_updates               | 15          |
# |    policy_gradient_loss    | -0.00149    |
# |    value_loss              | 0.109       |
# --------------------------------------------
# ---------------------------------------------
# | lux/                       |              |
# |    energy_collected        | 0            |
# |    final_reward            | 26.1         |
# |    map_coverage            | 10.9         |
# |    new_tiles_revealed      | 4            |
# |    point_reward            | 0            |
# |    points_earned           | 0            |
# |    relic_control_streak    | 0            |
# |    relic_point_tiles_found | 0            |
# |    rule_reward             | 26.1         |
# |    sap_actions_taken       | 1            |
# |    sap_reward              | 0            |
# |    total_energy            | 194          |
# |    visited_tiles_count     | 27           |
# |    win_rate                | 0            |
# | time/                      |              |
# |    fps                     | 95           |
# |    iterations              | 5            |
# |    time_elapsed            | 853          |
# |    total_timesteps         | 81920        |
# | train/                     |              |
# |    approx_kl               | 0.0020423853 |
# |    clip_fraction           | 0.00801      |
# |    clip_range              | 0.2          |
# |    clip_range_vf           | 0.2          |
# |    entropy_loss            | -28.7        |
# |    explained_variance      | 0.0651       |
# |    learning_rate           | 0.000474     |
# |    loss                    | -86          |
# |    n_updates               | 20           |
# |    policy_gradient_loss    | -0.00432     |
# |    value_loss              | 0.0348       |
# ---------------------------------------------
# ---------------------------------------------
# | lux/                       |              |
# |    energy_collected        | 0            |
# |    final_reward            | -6.34        |
# |    map_coverage            | 16           |
# |    new_tiles_revealed      | 1            |
# |    point_reward            | 0            |
# |    points_earned           | 0            |
# |    relic_control_streak    | 0            |
# |    relic_point_tiles_found | 0            |
# |    rule_reward             | -6.34        |
# |    sap_actions_taken       | 3            |
# |    sap_reward              | -2           |
# |    total_energy            | 220          |
# |    visited_tiles_count     | 37           |
# |    win_rate                | 0            |
# | time/                      |              |
# |    fps                     | 95           |
# |    iterations              | 6            |
# |    time_elapsed            | 1029         |
# |    total_timesteps         | 98304        |
# | train/                     |              |
# |    approx_kl               | 0.0025903434 |
# |    clip_fraction           | 0.013        |
# |    clip_range              | 0.2          |
# |    clip_range_vf           | 0.2          |
# |    entropy_loss            | -28.7        |
# |    explained_variance      | 0.315        |
# |    learning_rate           | 0.000467     |
# |    loss                    | -86          |
# |    n_updates               | 25           |
# |    policy_gradient_loss    | -0.00609     |
# |    value_loss              | 0.00657      |
# ---------------------------------------------
# ---------------------------------------------
# | lux/                       |              |
# |    energy_collected        | 1            |
# |    final_reward            | -5.51        |
# |    map_coverage            | 25.3         |
# |    new_tiles_revealed      | 0            |
# |    point_reward            | 0            |
# |    points_earned           | 0            |
# |    relic_control_streak    | 0            |
# |    relic_point_tiles_found | 0            |
# |    rule_reward             | -5.51        |
# |    sap_actions_taken       | 2            |
# |    sap_reward              | -1           |
# |    total_energy            | 33           |
# |    visited_tiles_count     | 41           |
# |    win_rate                | 0            |
# | time/                      |              |
# |    fps                     | 95           |
# |    iterations              | 7            |
# |    time_elapsed            | 1201         |
# |    total_timesteps         | 114688       |
# | train/                     |              |
# |    approx_kl               | 0.0016447178 |
# |    clip_fraction           | 0.00646      |
# |    clip_range              | 0.2          |
# |    clip_range_vf           | 0.2          |
# |    entropy_loss            | -28.7        |
# |    explained_variance      | 0.249        |
# |    learning_rate           | 0.000461     |
# |    loss                    | -86          |
# |    n_updates               | 30           |
# |    policy_gradient_loss    | -0.00323     |
# |    value_loss              | 0.00678      |
# ---------------------------------------------
# ---------------------------------------------
# | lux/                       |              |
# |    energy_collected        | 37           |
# |    final_reward            | -7.16        |
# |    map_coverage            | 22.4         |
# |    new_tiles_revealed      | 3            |
# |    point_reward            | 1            |
# |    points_earned           | 0            |
# |    relic_control_streak    | 0            |
# |    relic_point_tiles_found | 0            |
# |    rule_reward             | -7.16        |
# |    sap_actions_taken       | 5            |
# |    sap_reward              | -3           |
# |    total_energy            | 310          |
# |    visited_tiles_count     | 46           |
# |    win_rate                | 0.5          |
# | time/                      |              |
# |    fps                     | 95           |
# |    iterations              | 8            |
# |    time_elapsed            | 1373         |
# |    total_timesteps         | 131072       |
# | train/                     |              |
# |    approx_kl               | 0.0017929014 |
# |    clip_fraction           | 0.00795      |
# |    clip_range              | 0.2          |
# |    clip_range_vf           | 0.2          |
# |    entropy_loss            | -28.7        |
# |    explained_variance      | 0.558        |
# |    learning_rate           | 0.000454     |
# |    loss                    | -86          |
# |    n_updates               | 35           |
# |    policy_gradient_loss    | -0.00453     |
# |    value_loss              | 0.00346      |
# ---------------------------------------------
# ---------------------------------------------
# | lux/                       |              |
# |    energy_collected        | 14           |
# |    final_reward            | -10.2        |
# |    map_coverage            | 26.7         |
# |    new_tiles_revealed      | 2            |
# |    point_reward            | 0            |
# |    points_earned           | 0            |
# |    relic_control_streak    | 0            |
# |    relic_point_tiles_found | 0            |
# |    rule_reward             | -10.2        |
# |    sap_actions_taken       | 1            |
# |    sap_reward              | -1           |
# |    total_energy            | 222          |
# |    visited_tiles_count     | 53           |
# |    win_rate                | 0            |
# | time/                      |              |
# |    fps                     | 95           |
# |    iterations              | 9            |
# |    time_elapsed            | 1545         |
# |    total_timesteps         | 147456       |
# | train/                     |              |
# |    approx_kl               | 0.0013835622 |
# |    clip_fraction           | 0.00519      |
# |    clip_range              | 0.2          |
# |    clip_range_vf           | 0.2          |
# |    entropy_loss            | -28.7        |
# |    explained_variance      | 0.493        |
# |    learning_rate           | 0.000448     |
# |    loss                    | -86          |
# |    n_updates               | 40           |
# |    policy_gradient_loss    | -0.00299     |
# |    value_loss              | 0.00595      |
# ---------------------------------------------
# ---------------------------------------------
# | lux/                       |              |
# |    energy_collected        | 4            |
# |    final_reward            | -15.3        |
# |    map_coverage            | 38           |
# |    new_tiles_revealed      | 6            |
# |    point_reward            | 1            |
# |    points_earned           | 0            |
# |    relic_control_streak    | 0            |
# |    relic_point_tiles_found | 0            |
# |    rule_reward             | -15.3        |
# |    sap_actions_taken       | 3            |
# |    sap_reward              | -2           |
# |    total_energy            | 242          |
# |    visited_tiles_count     | 87           |
# |    win_rate                | 0.5          |
# | time/                      |              |
# |    fps                     | 95           |
# |    iterations              | 10           |
# |    time_elapsed            | 1717         |
# |    total_timesteps         | 163840       |
# | train/                     |              |
# |    approx_kl               | 0.0013216295 |
# |    clip_fraction           | 0.0061       |
# |    clip_range              | 0.2          |
# |    clip_range_vf           | 0.2          |
# |    entropy_loss            | -28.7        |
# |    explained_variance      | 0.234        |
# |    learning_rate           | 0.000441     |
# |    loss                    | -86          |
# |    n_updates               | 45           |
# |    policy_gradient_loss    | -0.00172     |
# |    value_loss              | 0.0473       |
# ---------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 1             |
# |    final_reward            | -26.3         |
# |    map_coverage            | 16.7          |
# |    new_tiles_revealed      | 2             |
# |    point_reward            | 1             |
# |    points_earned           | 0             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 51            |
# |    rule_reward             | -26.3         |
# |    sap_actions_taken       | 3             |
# |    sap_reward              | -2            |
# |    total_energy            | 189           |
# |    visited_tiles_count     | 62            |
# |    win_rate                | 0.333         |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 11            |
# |    time_elapsed            | 1890          |
# |    total_timesteps         | 180224        |
# | train/                     |               |
# |    approx_kl               | 0.00084437797 |
# |    clip_fraction           | 0.00273       |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.684         |
# |    learning_rate           | 0.000434      |
# |    loss                    | -86           |
# |    n_updates               | 50            |
# |    policy_gradient_loss    | -0.00184      |
# |    value_loss              | 0.00255       |
# ----------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 0             |
# |    final_reward            | 3.88          |
# |    map_coverage            | 24.7          |
# |    new_tiles_revealed      | 7             |
# |    point_reward            | 0             |
# |    points_earned           | 0             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 0             |
# |    rule_reward             | 3.88          |
# |    sap_actions_taken       | 3             |
# |    sap_reward              | -3            |
# |    total_energy            | 217           |
# |    visited_tiles_count     | 57            |
# |    win_rate                | 0             |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 12            |
# |    time_elapsed            | 2063          |
# |    total_timesteps         | 196608        |
# | train/                     |               |
# |    approx_kl               | 0.00067133177 |
# |    clip_fraction           | 0.0015        |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.419         |
# |    learning_rate           | 0.000428      |
# |    loss                    | -86           |
# |    n_updates               | 55            |
# |    policy_gradient_loss    | -0.001        |
# |    value_loss              | 0.0378        |
# ----------------------------------------------
# -------------------------------------------
# | lux/                       |            |
# |    energy_collected        | 0          |
# |    final_reward            | 67         |
# |    map_coverage            | 42.7       |
# |    new_tiles_revealed      | 0          |
# |    point_reward            | 1          |
# |    points_earned           | 3          |
# |    relic_control_streak    | 0          |
# |    relic_point_tiles_found | 51         |
# |    rule_reward             | 67         |
# |    sap_actions_taken       | 4          |
# |    sap_reward              | -4         |
# |    total_energy            | 825        |
# |    visited_tiles_count     | 76         |
# |    win_rate                | 0.333      |
# | time/                      |            |
# |    fps                     | 95         |
# |    iterations              | 13         |
# |    time_elapsed            | 2236       |
# |    total_timesteps         | 212992     |
# | train/                     |            |
# |    approx_kl               | 0.00070473 |
# |    clip_fraction           | 0.000745   |
# |    clip_range              | 0.2        |
# |    clip_range_vf           | 0.2        |
# |    entropy_loss            | -28.7      |
# |    explained_variance      | 0.57       |
# |    learning_rate           | 0.000421   |
# |    loss                    | -86        |
# |    n_updates               | 60         |
# |    policy_gradient_loss    | -0.00135   |
# |    value_loss              | 0.0292     |
# -------------------------------------------
# ---------------------------------------------
# | lux/                       |              |
# |    energy_collected        | 1            |
# |    final_reward            | -14.5        |
# |    map_coverage            | 16.7         |
# |    new_tiles_revealed      | 2            |
# |    point_reward            | 2            |
# |    points_earned           | 0            |
# |    relic_control_streak    | 0            |
# |    relic_point_tiles_found | 0            |
# |    rule_reward             | -14.5        |
# |    sap_actions_taken       | 1            |
# |    sap_reward              | -0.5         |
# |    total_energy            | 272          |
# |    visited_tiles_count     | 52           |
# |    win_rate                | 0.667        |
# | time/                      |              |
# |    fps                     | 95           |
# |    iterations              | 14           |
# |    time_elapsed            | 2409         |
# |    total_timesteps         | 229376       |
# | train/                     |              |
# |    approx_kl               | 0.0009252664 |
# |    clip_fraction           | 0.000647     |
# |    clip_range              | 0.2          |
# |    clip_range_vf           | 0.2          |
# |    entropy_loss            | -28.7        |
# |    explained_variance      | 0.611        |
# |    learning_rate           | 0.000415     |
# |    loss                    | -86          |
# |    n_updates               | 65           |
# |    policy_gradient_loss    | -0.00146     |
# |    value_loss              | 0.0129       |
# ---------------------------------------------
# ---------------------------------------------
# | lux/                       |              |
# |    energy_collected        | 96           |
# |    final_reward            | -42.6        |
# |    map_coverage            | 27.1         |
# |    new_tiles_revealed      | 0            |
# |    point_reward            | 2            |
# |    points_earned           | 0            |
# |    relic_control_streak    | 0            |
# |    relic_point_tiles_found | 20           |
# |    rule_reward             | -42.6        |
# |    sap_actions_taken       | 3            |
# |    sap_reward              | -3           |
# |    total_energy            | 349          |
# |    visited_tiles_count     | 84           |
# |    win_rate                | 0.5          |
# | time/                      |              |
# |    fps                     | 95           |
# |    iterations              | 15           |
# |    time_elapsed            | 2582         |
# |    total_timesteps         | 245760       |
# | train/                     |              |
# |    approx_kl               | 0.0006378311 |
# |    clip_fraction           | 0.000171     |
# |    clip_range              | 0.2          |
# |    clip_range_vf           | 0.2          |
# |    entropy_loss            | -28.7        |
# |    explained_variance      | 0.538        |
# |    learning_rate           | 0.000408     |
# |    loss                    | -86          |
# |    n_updates               | 70           |
# |    policy_gradient_loss    | -0.000903    |
# |    value_loss              | 0.0417       |
# ---------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 0             |
# |    final_reward            | 54            |
# |    map_coverage            | 33.3          |
# |    new_tiles_revealed      | 1             |
# |    point_reward            | 3             |
# |    points_earned           | 0             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 90            |
# |    rule_reward             | 54            |
# |    sap_actions_taken       | 2             |
# |    sap_reward              | -2            |
# |    total_energy            | 857           |
# |    visited_tiles_count     | 92            |
# |    win_rate                | 0.75          |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 16            |
# |    time_elapsed            | 2754          |
# |    total_timesteps         | 262144        |
# | train/                     |               |
# |    approx_kl               | 0.00062540674 |
# |    clip_fraction           | 0.000281      |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.51          |
# |    learning_rate           | 0.000402      |
# |    loss                    | -86           |
# |    n_updates               | 75            |
# |    policy_gradient_loss    | -0.000969     |
# |    value_loss              | 0.127         |
# ----------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 0             |
# |    final_reward            | 70.3          |
# |    map_coverage            | 18.2          |
# |    new_tiles_revealed      | 3             |
# |    point_reward            | 0             |
# |    points_earned           | 9             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 36            |
# |    rule_reward             | 70.3          |
# |    sap_actions_taken       | 1             |
# |    sap_reward              | -1            |
# |    total_energy            | 153           |
# |    visited_tiles_count     | 60            |
# |    win_rate                | 0             |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 17            |
# |    time_elapsed            | 2926          |
# |    total_timesteps         | 278528        |
# | train/                     |               |
# |    approx_kl               | 0.00067696726 |
# |    clip_fraction           | 0.000171      |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.645         |
# |    learning_rate           | 0.000395      |
# |    loss                    | -86           |
# |    n_updates               | 80            |
# |    policy_gradient_loss    | -0.00111      |
# |    value_loss              | 0.0375        |
# ----------------------------------------------
# ---------------------------------------------
# | lux/                       |              |
# |    energy_collected        | 19           |
# |    final_reward            | 58.7         |
# |    map_coverage            | 22           |
# |    new_tiles_revealed      | 4            |
# |    point_reward            | 2            |
# |    points_earned           | 1            |
# |    relic_control_streak    | 0            |
# |    relic_point_tiles_found | 52           |
# |    rule_reward             | 58.7         |
# |    sap_actions_taken       | 3            |
# |    sap_reward              | -3           |
# |    total_energy            | 261          |
# |    visited_tiles_count     | 89           |
# |    win_rate                | 0.5          |
# | time/                      |              |
# |    fps                     | 95           |
# |    iterations              | 18           |
# |    time_elapsed            | 3101         |
# |    total_timesteps         | 294912       |
# | train/                     |              |
# |    approx_kl               | 0.0006435397 |
# |    clip_fraction           | 6.1e-05      |
# |    clip_range              | 0.2          |
# |    clip_range_vf           | 0.2          |
# |    entropy_loss            | -28.7        |
# |    explained_variance      | 0.726        |
# |    learning_rate           | 0.000389     |
# |    loss                    | -86          |
# |    n_updates               | 85           |
# |    policy_gradient_loss    | -0.000704    |
# |    value_loss              | 0.0193       |
# ---------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 3             |
# |    final_reward            | 1.04          |
# |    map_coverage            | 6.08          |
# |    new_tiles_revealed      | 0             |
# |    point_reward            | 0             |
# |    points_earned           | 0             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 0             |
# |    rule_reward             | 1.04          |
# |    sap_actions_taken       | 4             |
# |    sap_reward              | 0             |
# |    total_energy            | 302           |
# |    visited_tiles_count     | 7             |
# |    win_rate                | 0             |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 19            |
# |    time_elapsed            | 3273          |
# |    total_timesteps         | 311296        |
# | train/                     |               |
# |    approx_kl               | 0.00044786447 |
# |    clip_fraction           | 0             |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.714         |
# |    learning_rate           | 0.000382      |
# |    loss                    | -86           |
# |    n_updates               | 90            |
# |    policy_gradient_loss    | -0.000507     |
# |    value_loss              | 0.0428        |
# ----------------------------------------------
# ---------------------------------------------
# | lux/                       |              |
# |    energy_collected        | 0            |
# |    final_reward            | 15.2         |
# |    map_coverage            | 17           |
# |    new_tiles_revealed      | 0            |
# |    point_reward            | 0            |
# |    points_earned           | 0            |
# |    relic_control_streak    | 0            |
# |    relic_point_tiles_found | 0            |
# |    rule_reward             | 15.2         |
# |    sap_actions_taken       | 2            |
# |    sap_reward              | 0            |
# |    total_energy            | 19           |
# |    visited_tiles_count     | 20           |
# |    win_rate                | 0            |
# | time/                      |              |
# |    fps                     | 95           |
# |    iterations              | 20           |
# |    time_elapsed            | 3443         |
# |    total_timesteps         | 327680       |
# | train/                     |              |
# |    approx_kl               | 0.0005281763 |
# |    clip_fraction           | 0            |
# |    clip_range              | 0.2          |
# |    clip_range_vf           | 0.2          |
# |    entropy_loss            | -28.7        |
# |    explained_variance      | 0.499        |
# |    learning_rate           | 0.000375     |
# |    loss                    | -86          |
# |    n_updates               | 95           |
# |    policy_gradient_loss    | -0.000751    |
# |    value_loss              | 0.137        |
# ---------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 1             |
# |    final_reward            | 13.8          |
# |    map_coverage            | 16.5          |
# |    new_tiles_revealed      | 2             |
# |    point_reward            | 0             |
# |    points_earned           | 0             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 0             |
# |    rule_reward             | 13.8          |
# |    sap_actions_taken       | 5             |
# |    sap_reward              | -2            |
# |    total_energy            | 69            |
# |    visited_tiles_count     | 30            |
# |    win_rate                | 0             |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 21            |
# |    time_elapsed            | 3615          |
# |    total_timesteps         | 344064        |
# | train/                     |               |
# |    approx_kl               | 0.00045446848 |
# |    clip_fraction           | 0             |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.59          |
# |    learning_rate           | 0.000369      |
# |    loss                    | -86           |
# |    n_updates               | 100           |
# |    policy_gradient_loss    | -0.000752     |
# |    value_loss              | 0.104         |
# ----------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 77            |
# |    final_reward            | 5.13          |
# |    map_coverage            | 30.6          |
# |    new_tiles_revealed      | 0             |
# |    point_reward            | 0             |
# |    points_earned           | 0             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 19            |
# |    rule_reward             | 5.13          |
# |    sap_actions_taken       | 2             |
# |    sap_reward              | 0             |
# |    total_energy            | 253           |
# |    visited_tiles_count     | 33            |
# |    win_rate                | 0             |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 22            |
# |    time_elapsed            | 3789          |
# |    total_timesteps         | 360448        |
# | train/                     |               |
# |    approx_kl               | 0.00036513433 |
# |    clip_fraction           | 0             |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.537         |
# |    learning_rate           | 0.000362      |
# |    loss                    | -86           |
# |    n_updates               | 105           |
# |    policy_gradient_loss    | -0.000246     |
# |    value_loss              | 0.0256        |
# ----------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 4             |
# |    final_reward            | -5.38         |
# |    map_coverage            | 17.2          |
# |    new_tiles_revealed      | 1             |
# |    point_reward            | 0             |
# |    points_earned           | 0             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 0             |
# |    rule_reward             | -5.38         |
# |    sap_actions_taken       | 1             |
# |    sap_reward              | -1            |
# |    total_energy            | 367           |
# |    visited_tiles_count     | 27            |
# |    win_rate                | 0             |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 23            |
# |    time_elapsed            | 3961          |
# |    total_timesteps         | 376832        |
# | train/                     |               |
# |    approx_kl               | 0.00037464412 |
# |    clip_fraction           | 0             |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.65          |
# |    learning_rate           | 0.000356      |
# |    loss                    | -86           |
# |    n_updates               | 110           |
# |    policy_gradient_loss    | -0.000635     |
# |    value_loss              | 0.0133        |
# ----------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 0             |
# |    final_reward            | 96.3          |
# |    map_coverage            | 35.6          |
# |    new_tiles_revealed      | 0             |
# |    point_reward            | 0             |
# |    points_earned           | 36            |
# |    relic_control_streak    | 18            |
# |    relic_point_tiles_found | 17            |
# |    rule_reward             | 96.3          |
# |    sap_actions_taken       | 3             |
# |    sap_reward              | 0             |
# |    total_energy            | 127           |
# |    visited_tiles_count     | 38            |
# |    win_rate                | 0             |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 24            |
# |    time_elapsed            | 4135          |
# |    total_timesteps         | 393216        |
# | train/                     |               |
# |    approx_kl               | 0.00059083314 |
# |    clip_fraction           | 0             |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.718         |
# |    learning_rate           | 0.000349      |
# |    loss                    | -86           |
# |    n_updates               | 115           |
# |    policy_gradient_loss    | -0.00119      |
# |    value_loss              | 0.0292        |
# ----------------------------------------------
# ---------------------------------------------
# | lux/                       |              |
# |    energy_collected        | 0            |
# |    final_reward            | -5.3         |
# |    map_coverage            | 13.9         |
# |    new_tiles_revealed      | 6            |
# |    point_reward            | 0            |
# |    points_earned           | 0            |
# |    relic_control_streak    | 0            |
# |    relic_point_tiles_found | 0            |
# |    rule_reward             | -5.3         |
# |    sap_actions_taken       | 3            |
# |    sap_reward              | -2           |
# |    total_energy            | 73           |
# |    visited_tiles_count     | 55           |
# |    win_rate                | 0            |
# | time/                      |              |
# |    fps                     | 95           |
# |    iterations              | 25           |
# |    time_elapsed            | 4310         |
# |    total_timesteps         | 409600       |
# | train/                     |              |
# |    approx_kl               | 0.0006581384 |
# |    clip_fraction           | 0            |
# |    clip_range              | 0.2          |
# |    clip_range_vf           | 0.2          |
# |    entropy_loss            | -28.7        |
# |    explained_variance      | 0.753        |
# |    learning_rate           | 0.000343     |
# |    loss                    | -86          |
# |    n_updates               | 120          |
# |    policy_gradient_loss    | -0.000872    |
# |    value_loss              | 0.0944       |
# ---------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 0             |
# |    final_reward            | -5.26         |
# |    map_coverage            | 29.3          |
# |    new_tiles_revealed      | 7             |
# |    point_reward            | 1             |
# |    points_earned           | 0             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 0             |
# |    rule_reward             | -5.26         |
# |    sap_actions_taken       | 6             |
# |    sap_reward              | -2            |
# |    total_energy            | 628           |
# |    visited_tiles_count     | 73            |
# |    win_rate                | 0.5           |
# | time/                      |               |
# |    fps                     | 94            |
# |    iterations              | 26            |
# |    time_elapsed            | 4485          |
# |    total_timesteps         | 425984        |
# | train/                     |               |
# |    approx_kl               | 0.00052151957 |
# |    clip_fraction           | 0             |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.823         |
# |    learning_rate           | 0.000336      |
# |    loss                    | -86           |
# |    n_updates               | 125           |
# |    policy_gradient_loss    | -0.000639     |
# |    value_loss              | 0.148         |
# ----------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 0             |
# |    final_reward            | 49.3          |
# |    map_coverage            | 18.8          |
# |    new_tiles_revealed      | 4             |
# |    point_reward            | 1             |
# |    points_earned           | 1             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 20            |
# |    rule_reward             | 49.3          |
# |    sap_actions_taken       | 3             |
# |    sap_reward              | -2            |
# |    total_energy            | 82            |
# |    visited_tiles_count     | 42            |
# |    win_rate                | 0.5           |
# | time/                      |               |
# |    fps                     | 94            |
# |    iterations              | 27            |
# |    time_elapsed            | 4658          |
# |    total_timesteps         | 442368        |
# | train/                     |               |
# |    approx_kl               | 0.00039826363 |
# |    clip_fraction           | 0             |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.73          |
# |    learning_rate           | 0.00033       |
# |    loss                    | -86           |
# |    n_updates               | 130           |
# |    policy_gradient_loss    | -0.000677     |
# |    value_loss              | 0.0516        |
# ----------------------------------------------
# ---------------------------------------------
# | lux/                       |              |
# |    energy_collected        | 0            |
# |    final_reward            | 136          |
# |    map_coverage            | 24.3         |
# |    new_tiles_revealed      | 3            |
# |    point_reward            | 1            |
# |    points_earned           | 5            |
# |    relic_control_streak    | 3            |
# |    relic_point_tiles_found | 40           |
# |    rule_reward             | 136          |
# |    sap_actions_taken       | 1            |
# |    sap_reward              | -1           |
# |    total_energy            | 36           |
# |    visited_tiles_count     | 64           |
# |    win_rate                | 0.5          |
# | time/                      |              |
# |    fps                     | 94           |
# |    iterations              | 28           |
# |    time_elapsed            | 4830         |
# |    total_timesteps         | 458752       |
# | train/                     |              |
# |    approx_kl               | 0.0004196137 |
# |    clip_fraction           | 1.22e-05     |
# |    clip_range              | 0.2          |
# |    clip_range_vf           | 0.2          |
# |    entropy_loss            | -28.7        |
# |    explained_variance      | 0.434        |
# |    learning_rate           | 0.000323     |
# |    loss                    | -86          |
# |    n_updates               | 135          |
# |    policy_gradient_loss    | -0.000552    |
# |    value_loss              | 0.0124       |
# ---------------------------------------------
# ---------------------------------------------
# | lux/                       |              |
# |    energy_collected        | 98           |
# |    final_reward            | -45.7        |
# |    map_coverage            | 17           |
# |    new_tiles_revealed      | 0            |
# |    point_reward            | 0            |
# |    points_earned           | 0            |
# |    relic_control_streak    | 0            |
# |    relic_point_tiles_found | 0            |
# |    rule_reward             | -45.7        |
# |    sap_actions_taken       | 1            |
# |    sap_reward              | -1           |
# |    total_energy            | 183          |
# |    visited_tiles_count     | 62           |
# |    win_rate                | 0            |
# | time/                      |              |
# |    fps                     | 94           |
# |    iterations              | 29           |
# |    time_elapsed            | 5002         |
# |    total_timesteps         | 475136       |
# | train/                     |              |
# |    approx_kl               | 0.0005014607 |
# |    clip_fraction           | 0            |
# |    clip_range              | 0.2          |
# |    clip_range_vf           | 0.2          |
# |    entropy_loss            | -28.7        |
# |    explained_variance      | 0.817        |
# |    learning_rate           | 0.000316     |
# |    loss                    | -86          |
# |    n_updates               | 140          |
# |    policy_gradient_loss    | -0.000896    |
# |    value_loss              | 0.00765      |
# ---------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 0             |
# |    final_reward            | 35.5          |
# |    map_coverage            | 26.6          |
# |    new_tiles_revealed      | 0             |
# |    point_reward            | 1             |
# |    points_earned           | 1             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 40            |
# |    rule_reward             | 35.5          |
# |    sap_actions_taken       | 6             |
# |    sap_reward              | -5            |
# |    total_energy            | 202           |
# |    visited_tiles_count     | 49            |
# |    win_rate                | 0.333         |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 30            |
# |    time_elapsed            | 5173          |
# |    total_timesteps         | 491520        |
# | train/                     |               |
# |    approx_kl               | 0.00046961423 |
# |    clip_fraction           | 0             |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.735         |
# |    learning_rate           | 0.00031       |
# |    loss                    | -86           |
# |    n_updates               | 145           |
# |    policy_gradient_loss    | -0.000729     |
# |    value_loss              | 0.0271        |
# ----------------------------------------------
# ---------------------------------------------
# | lux/                       |              |
# |    energy_collected        | 13           |
# |    final_reward            | 204          |
# |    map_coverage            | 32.5         |
# |    new_tiles_revealed      | 1            |
# |    point_reward            | 0            |
# |    points_earned           | 23           |
# |    relic_control_streak    | 22           |
# |    relic_point_tiles_found | 32           |
# |    rule_reward             | 204          |
# |    sap_actions_taken       | 3            |
# |    sap_reward              | -2           |
# |    total_energy            | 688          |
# |    visited_tiles_count     | 69           |
# |    win_rate                | 0            |
# | time/                      |              |
# |    fps                     | 95           |
# |    iterations              | 31           |
# |    time_elapsed            | 5345         |
# |    total_timesteps         | 507904       |
# | train/                     |              |
# |    approx_kl               | 0.0005407265 |
# |    clip_fraction           | 0            |
# |    clip_range              | 0.2          |
# |    clip_range_vf           | 0.2          |
# |    entropy_loss            | -28.7        |
# |    explained_variance      | 0.622        |
# |    learning_rate           | 0.000303     |
# |    loss                    | -86          |
# ...
# ----------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 0             |
# |    final_reward            | -11.2         |
# |    map_coverage            | 22.6          |
# |    new_tiles_revealed      | 1             |
# |    point_reward            | 1             |
# |    points_earned           | 0             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 0             |
# |    rule_reward             | -11.2         |
# |    sap_actions_taken       | 2             |
# |    sap_reward              | -2            |
# |    total_energy            | 390           |
# |    visited_tiles_count     | 79            |
# |    win_rate                | 0.25          |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 53            |
# |    time_elapsed            | 9131          |
# |    total_timesteps         | 868352        |
# | train/                     |               |
# |    approx_kl               | 0.00027229788 |
# |    clip_fraction           | 0             |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.758         |
# |    learning_rate           | 0.000159      |
# |    loss                    | -86           |
# |    n_updates               | 260           |
# |    policy_gradient_loss    | -0.000656     |
# |    value_loss              | 0.0702        |
# ----------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 39            |
# |    final_reward            | -26           |
# |    map_coverage            | 37.3          |
# |    new_tiles_revealed      | 1             |
# |    point_reward            | 1             |
# |    points_earned           | 0             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 0             |
# |    rule_reward             | -26           |
# |    sap_actions_taken       | 2             |
# |    sap_reward              | -2            |
# |    total_energy            | 194           |
# |    visited_tiles_count     | 87            |
# |    win_rate                | 0.25          |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 54            |
# |    time_elapsed            | 9300          |
# |    total_timesteps         | 884736        |
# | train/                     |               |
# |    approx_kl               | 0.00029636116 |
# |    clip_fraction           | 0             |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.67          |
# |    learning_rate           | 0.000153      |
# |    loss                    | -86           |
# |    n_updates               | 265           |
# |    policy_gradient_loss    | -0.000655     |
# |    value_loss              | 0.0119        |
# ----------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 0             |
# |    final_reward            | 0.479         |
# |    map_coverage            | 7.47          |
# |    new_tiles_revealed      | 0             |
# |    point_reward            | 0             |
# |    points_earned           | 0             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 0             |
# |    rule_reward             | 0.479         |
# |    sap_actions_taken       | 2             |
# |    sap_reward              | 0             |
# |    total_energy            | 0             |
# |    visited_tiles_count     | 9             |
# |    win_rate                | 0             |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 55            |
# |    time_elapsed            | 9472          |
# |    total_timesteps         | 901120        |
# | train/                     |               |
# |    approx_kl               | 0.00024498263 |
# |    clip_fraction           | 0             |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.724         |
# |    learning_rate           | 0.000146      |
# |    loss                    | -86           |
# |    n_updates               | 270           |
# |    policy_gradient_loss    | -0.000596     |
# |    value_loss              | 0.0471        |
# ----------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 6             |
# |    final_reward            | -0.494        |
# |    map_coverage            | 8.33          |
# |    new_tiles_revealed      | 2             |
# |    point_reward            | 0             |
# |    points_earned           | 0             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 0             |
# |    rule_reward             | -0.494        |
# |    sap_actions_taken       | 3             |
# |    sap_reward              | -1            |
# |    total_energy            | 12            |
# |    visited_tiles_count     | 10            |
# |    win_rate                | 0             |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 56            |
# |    time_elapsed            | 9641          |
# |    total_timesteps         | 917504        |
# | train/                     |               |
# |    approx_kl               | 0.00021018129 |
# |    clip_fraction           | 0             |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.852         |
# |    learning_rate           | 0.00014       |
# |    loss                    | -86           |
# |    n_updates               | 275           |
# |    policy_gradient_loss    | -0.000479     |
# |    value_loss              | 0.114         |
# ----------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 0             |
# |    final_reward            | -0.176        |
# |    map_coverage            | 25.9          |
# |    new_tiles_revealed      | 3             |
# |    point_reward            | 0             |
# |    points_earned           | 0             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 0             |
# |    rule_reward             | -0.176        |
# |    sap_actions_taken       | 5             |
# |    sap_reward              | -1            |
# |    total_energy            | 95            |
# |    visited_tiles_count     | 20            |
# |    win_rate                | 0             |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 57            |
# |    time_elapsed            | 9811          |
# |    total_timesteps         | 933888        |
# | train/                     |               |
# |    approx_kl               | 0.00020534112 |
# |    clip_fraction           | 0             |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.765         |
# |    learning_rate           | 0.000133      |
# |    loss                    | -86           |
# |    n_updates               | 280           |
# |    policy_gradient_loss    | -0.000554     |
# |    value_loss              | 0.0186        |
# ----------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 1             |
# |    final_reward            | 6.38          |
# |    map_coverage            | 14.6          |
# |    new_tiles_revealed      | 6             |
# |    point_reward            | 0             |
# |    points_earned           | 0             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 0             |
# |    rule_reward             | 6.38          |
# |    sap_actions_taken       | 2             |
# |    sap_reward              | 0             |
# |    total_energy            | 296           |
# |    visited_tiles_count     | 24            |
# |    win_rate                | 0             |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 58            |
# |    time_elapsed            | 9981          |
# |    total_timesteps         | 950272        |
# | train/                     |               |
# |    approx_kl               | 0.00016044764 |
# |    clip_fraction           | 0             |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.764         |
# |    learning_rate           | 0.000126      |
# |    loss                    | -86           |
# |    n_updates               | 285           |
# |    policy_gradient_loss    | -0.000353     |
# |    value_loss              | 0.0416        |
# ----------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 25            |
# |    final_reward            | -9.91         |
# |    map_coverage            | 24.1          |
# |    new_tiles_revealed      | 0             |
# |    point_reward            | 1             |
# |    points_earned           | 0             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 0             |
# |    rule_reward             | -9.91         |
# |    sap_actions_taken       | 3             |
# |    sap_reward              | 0             |
# |    total_energy            | 61            |
# |    visited_tiles_count     | 13            |
# |    win_rate                | 1             |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 59            |
# |    time_elapsed            | 10153         |
# |    total_timesteps         | 966656        |
# | train/                     |               |
# |    approx_kl               | 0.00017283781 |
# |    clip_fraction           | 0             |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.783         |
# |    learning_rate           | 0.00012       |
# |    loss                    | -86           |
# |    n_updates               | 290           |
# |    policy_gradient_loss    | -0.000501     |
# |    value_loss              | 0.0265        |
# ----------------------------------------------
# ---------------------------------------------
# | lux/                       |              |
# |    energy_collected        | 5            |
# |    final_reward            | 16.2         |
# |    map_coverage            | 26.9         |
# |    new_tiles_revealed      | 3            |
# |    point_reward            | 0            |
# |    points_earned           | 9            |
# |    relic_control_streak    | 0            |
# |    relic_point_tiles_found | 35           |
# |    rule_reward             | 16.2         |
# |    sap_actions_taken       | 1            |
# |    sap_reward              | 0            |
# |    total_energy            | 196          |
# |    visited_tiles_count     | 60           |
# |    win_rate                | 0            |
# | time/                      |              |
# |    fps                     | 95           |
# |    iterations              | 60           |
# |    time_elapsed            | 10331        |
# |    total_timesteps         | 983040       |
# | train/                     |              |
# |    approx_kl               | 0.0001353482 |
# |    clip_fraction           | 0            |
# |    clip_range              | 0.2          |
# |    clip_range_vf           | 0.2          |
# |    entropy_loss            | -28.7        |
# |    explained_variance      | 0.761        |
# |    learning_rate           | 0.000113     |
# |    loss                    | -86          |
# |    n_updates               | 295          |
# |    policy_gradient_loss    | -0.000353    |
# |    value_loss              | 0.0116       |
# ---------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 0             |
# |    final_reward            | 1.58          |
# |    map_coverage            | 29.9          |
# |    new_tiles_revealed      | 0             |
# |    point_reward            | 0             |
# |    points_earned           | 0             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 0             |
# |    rule_reward             | 1.58          |
# |    sap_actions_taken       | 4             |
# |    sap_reward              | -4            |
# |    total_energy            | 236           |
# |    visited_tiles_count     | 55            |
# |    win_rate                | 0             |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 61            |
# |    time_elapsed            | 10511         |
# |    total_timesteps         | 999424        |
# | train/                     |               |
# |    approx_kl               | 0.00014156202 |
# |    clip_fraction           | 0             |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.836         |
# |    learning_rate           | 0.000107      |
# |    loss                    | -86           |
# |    n_updates               | 300           |
# |    policy_gradient_loss    | -0.000507     |
# |    value_loss              | 0.0109        |
# ----------------------------------------------
# ----------------------------------------------
# | lux/                       |               |
# |    energy_collected        | 111           |
# |    final_reward            | -20.7         |
# |    map_coverage            | 23.6          |
# |    new_tiles_revealed      | 0             |
# |    point_reward            | 1             |
# |    points_earned           | 0             |
# |    relic_control_streak    | 0             |
# |    relic_point_tiles_found | 0             |
# |    rule_reward             | -20.7         |
# |    sap_actions_taken       | 1             |
# |    sap_reward              | -1            |
# |    total_energy            | 454           |
# |    visited_tiles_count     | 53            |
# |    win_rate                | 0.5           |
# | time/                      |               |
# |    fps                     | 95            |
# |    iterations              | 62            |
# |    time_elapsed            | 10685         |
# |    total_timesteps         | 1015808       |
# | train/                     |               |
# |    approx_kl               | 0.00010021457 |
# |    clip_fraction           | 0             |
# |    clip_range              | 0.2           |
# |    clip_range_vf           | 0.2           |
# |    entropy_loss            | -28.7         |
# |    explained_variance      | 0.793         |
# |    learning_rate           | 0.0001        |
# |    loss                    | -86           |
# |    n_updates               | 305           |
# |    policy_gradient_loss    | -0.000319     |
# |    value_loss              | 0.0143        |
# ----------------------------------------------
