# %%
# !luxai-s3 kits/python/main.py kits/python/main.py --output=replay.html
# Out:
# player_0, kits/python/main.py: Player player_0 (Team ID: 0, Policy: p0): Attempting to load RLlib RLModule...
#
# player_1, kits/python/main.py: Player player_1 (Team ID: 1, Policy: p1): Attempting to load RLlib RLModule...
#
# player_1, kits/python/main.py: 2025-04-27 18:39:47,573	WARNING deprecation.py:50 -- DeprecationWarning: `RLModule(config=[RLModuleConfig object])` has been deprecated. Use `RLModule(observation_space=.., action_space=.., inference_only=.., model_config=.., catalog_class=..)` instead. This will raise an error in the future!
#
# player_0, kits/python/main.py: 2025-04-27 18:39:47,577	WARNING deprecation.py:50 -- DeprecationWarning: `RLModule(config=[RLModuleConfig object])` has been deprecated. Use `RLModule(observation_space=.., action_space=.., inference_only=.., model_config=.., catalog_class=..)` instead. This will raise an error in the future!
#
# player_1, kits/python/main.py: Traceback (most recent call last):
#
# ...
